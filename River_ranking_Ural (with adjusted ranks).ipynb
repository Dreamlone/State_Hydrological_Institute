# %% [markdown]
# # Определение порядка водотоков
#
# Для подготовки данных были произведены следующие действия:
# * Перевод слоя полигональных объектов в линейные: ВЕКТОР - ОБРАБОТКА ГЕОМЕТРИИ - ПРЕОБРАЗОВАТЬ ПОЛИГОНЫ В ЛИНИИ (QGIS)
# * Объединение линейных векторных слоев: ВЕКТОР - ГЕООБРАБОТКА - ОБЪЕДИНЕНИЕ (QGIS)
# * Разбиение линий на сегменты: АНАЛИЗ - ВЕКТОРНЫЙ ОВЕРЛЕЙ - РАЗБИТЬ ЛИНИЯМИ (QGIS)
# * Задание новых полей с индексами: PYTHON
# * Извлечение вершин на пересечениях сегментов: ВЕКТОР - АНАЛИЗ - ПЕРЕСЕЧЕНИЯ ЛИНИЙ (QGIS)
#
# В результате преобразований был получен следующий векторный слой: v_new.shp

# %%
# Загрузим все нужные библиотеки 
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import random
import time
import networkx as nx
import pandas as pd
import geopandas, geoplot
import timeit

from pylab import rcParams
rcParams['figure.figsize'] = 11, 7

# %% [markdown]
# Алгоритм хеширования идентификаторов сегментов

# %%
# Присваивание новых идентефикаторов слою с реками (сегментами рек)
r = geopandas.read_file('/media/mikhail/Data1/Ob/Ural/All_segments.shp')
# Сортируем по тому полю, по которому будем производить "хеширование"
# Важный момент - Сортируем датафрейм
r = r.sort_values(by = 'ID')
r.head(2)
# Out:
#      fid     ID      L_CODE              NAME  fid_2  ID_2  L_CODE_2 TEXT_  \
# 0  140.0  140.0  25400092.0  ÐÐ°Ð³ÑÑÐ»Ð°Ð¹    NaN   NaN       NaN  None
# 1  140.0  140.0  25400092.0  ÐÐ°Ð³ÑÑÐ»Ð°Ð¹    NaN   NaN       NaN  None
#
#   NAME_POLT NAME_2  Ð¾ÑÐ±Ð¾Ñ  \
# 0      None   None         NaN
# 1      None   None         NaN
#
#                                             geometry
# 0  LINESTRING (51.71059 49.36370, 51.71634 49.355...
# 1  LINESTRING (51.69427 49.07898, 51.69512 49.049...

# %%
# Функция генерации нового поля
def generate_id(field, new_name, table, gap_field = -9999):
    # Присвоим каждому объекту свой новый ID на основе значения поля ID
    indexes = np.array(table[field])
    New_ID = []
    for element in range(0, len(indexes)):
        # Сравнение последующих значений с предыдущими
        if element == 0:
            counter = 0
            gap_counter = 0
            new_id = str(indexes[element]) + ':' + str(counter)            
            
            # Если значения в ячейке нет, то
            if str(indexes[element]) == 'nan':
                new_id = str(gap_field) + ':' + str(gap_counter)
                gap_counter += 1
            New_ID.append(new_id)
        else:
            past_ID = indexes[element -1]
            current_ID = indexes[element]
            # Если идентификатор такой же, какой и был ранее
            if current_ID == past_ID:
                # То мы имеем дело с той же самой рекой
                counter += 1  
            else:            
                counter = 0
            new_id = str(indexes[element]) + ':' + str(counter)
            
            # Если значения в ячейке нет
            if str(indexes[element]) == 'nan':
                new_id = str(gap_field) + ':' + str(gap_counter)
                gap_counter += 1
                
            New_ID.append(new_id)
    
    table[new_name] = New_ID
    # Оставляем только 2 столбца
    table = table[['geometry', field, new_name]]
    return(table)

# Применяем алгоритм
table = generate_id(field = 'ID', new_name = 'NEW_ID', table = r)
# Сохраним все в файл
table.to_file('/media/mikhail/Data1/Ob/Ural/Ural_rivers.shp')

# %% [markdown]
# ## Препроцессинг

# %%
# Загрузим все нужные библиотеки 
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import random
import time
import networkx as nx
import pandas as pd
import geopandas, geoplot
import timeit

from pylab import rcParams
rcParams['figure.figsize'] = 11, 7

l_data = geopandas.read_file('/media/mikhail/Data1/Ob/URAL_test/split_with_length.shp')
# Составляем датафрейм, где присутствуют данные об идентификаторах и длинах сегментов рек
dataframe = pd.DataFrame(l_data[['length', 'id']])
# Загружаем данные с разделенными по пересечениям
data = geopandas.read_file('/media/mikhail/Data1/Ob/URAL_test/points_with_length.shp')

# %% [markdown]
# ## Формирование графа
#
# На данном этапе данные можно описать следующим образом. Точки находятся на пересечениях сегментов. Все сегменты рек проиндексированы в поле NEW, все реки (которые состоят из нескольких сегментов) проиндексированы с помощью значений поля id. В результате определения точек пересечния сегментов, таблица атрибутов была преобразована. Были сформированы поля id_2 и NEW_2 - то есть точка характеризуется двуям парами полей: "id" и "NEW". Рассмотрим пару полей NEW и NEW_2, так как в дальнейшем будем использовать именно их. Каждая строка - это точка пересчения сегментов, в таком случае сегмент реки NEW через данную точку имеет пересечение с NEW_2.
#
# Таким образом, если рассматривать сегменты реки как вершины, а их связи/пересечения как ребра, то таблицу, составленную из полей NEW и NEW2 можно воспринимать как список смежности.

# %%
list_of_adjacencies = data[['id', 'id_2']]
list_of_adjacencies = np.array(list_of_adjacencies)

# Функция для приведения списка смежности к нужному формату
def prepare(list_of_adjacencies):
    lines = []
    for i in list_of_adjacencies:
        i_0 = str(i[0])
        i_1 = str(i[1])
        string = i_0 + ' ' + i_1
        lines.append(string)
    return(lines)

lines = prepare(list_of_adjacencies)
G = nx.parse_adjlist(lines, nodetype = int)
print('Было: \n', list_of_adjacencies[0:2], '\n')
print('Стало: \n', lines[0:2], '\n')
# Посмотрим, корректно ли мы опередили граф
print('Список всех вершин (сегментов реки):', G.nodes())
# Out:
# Было:
#  [[  1  83]
#  [  1 194]]
#
# Стало:
#  ['1 83', '1 194']
#
# Список всех вершин (сегментов реки): [1, 83, 194, 195, 234, 2, 203, 3, 175, 235, 249, 432, 4, 8, 177, 178, 5, 330, 331, 6, 169, 170, 180, 436, 7, 186, 9, 335, 337, 10, 176, 224, 11, 187, 12, 210, 13, 236, 14, 246, 15, 149, 367, 16, 17, 81, 18, 278, 420, 20, 263, 21, 108, 109, 22, 23, 265, 24, 250, 266, 25, 358, 26, 68, 69, 27, 252, 253, 28, 115, 116, 354, 355, 29, 254, 30, 299, 316, 31, 281, 282, 32, 329, 33, 34, 77, 35, 284, 36, 418, 421, 37, 38, 78, 39, 89, 90, 40, 91, 41, 43, 44, 262, 42, 294, 318, 362, 45, 51, 319, 322, 46, 87, 47, 82, 261, 48, 49, 151, 293, 321, 50, 139, 52, 84, 85, 53, 123, 54, 138, 55, 104, 56, 385, 386, 57, 58, 381, 384, 59, 269, 60, 369, 371, 61, 295, 310, 62, 239, 240, 63, 64, 95, 370, 65, 373, 374, 66, 193, 196, 67, 72, 375, 70, 230, 232, 71, 229, 73, 336, 74, 171, 172, 332, 75, 199, 76, 301, 300, 227, 228, 79, 243, 244, 80, 298, 303, 213, 214, 217, 218, 86, 198, 201, 302, 311, 88, 219, 312, 92, 238, 242, 93, 205, 206, 94, 334, 96, 349, 97, 98, 406, 437, 438, 99, 101, 102, 320, 327, 100, 152, 103, 366, 105, 106, 426, 427, 107, 341, 346, 387, 388, 110, 389, 390, 111, 409, 412, 413, 112, 393, 394, 414, 415, 113, 114, 145, 166, 167, 184, 117, 137, 118, 119, 155, 215, 216, 120, 121, 220, 122, 383, 124, 339, 340, 125, 380, 382, 126, 363, 364, 127, 357, 128, 129, 344, 345, 130, 131, 132, 134, 133, 221, 135, 142, 259, 296, 297, 136, 144, 148, 323, 324, 185, 325, 326, 140, 360, 141, 361, 143, 160, 146, 439, 440, 147, 183, 442, 443, 150, 223, 225, 153, 154, 156, 161, 157, 430, 431, 158, 159, 342, 343, 162, 163, 433, 434, 164, 396, 352, 395, 168, 353, 403, 404, 410, 411, 273, 173, 233, 416, 417, 174, 377, 425, 429, 179, 247, 181, 307, 308, 305, 306, 188, 304, 309, 189, 190, 192, 197, 276, 191, 275, 202, 212, 200, 372, 222, 271, 277, 204, 333, 207, 208, 398, 399, 209, 315, 226, 283, 313, 231, 272, 237, 241, 287, 317, 274, 245, 368, 248, 378, 314, 251, 267, 268, 348, 255, 257, 258, 328, 256, 288, 260, 285, 286, 264, 289, 290, 350, 291, 270, 279, 423, 424, 280, 376, 292, 359, 379, 338, 351, 422, 407, 408, 428, 347, 400, 401, 402, 356, 391, 392, 365, 441, 419]

# %% [markdown]
# Визуализируем граф

# %%
nx.draw(G,pos=nx.spring_layout(G), with_labels=False, node_color='#1E90FF', node_size=10)

# %% [markdown]
# Стоит обратить внимание, что граф, составленный по гидрологической сети таким образом содержит много циклов.
#
# Основные этапы обработки можно описать в виде схемы:
# ![Flow.png](https://raw.githubusercontent.com/Dreamlone/State_Hydrological_Institute/master/images/flow.png)
#
# Первые этапы выполнялись над векторным слоем водотоков в геоинформационной системе QGIS. Алгоритм обхода графа осуществлялся с помощью скриптов на Python.

# %% [markdown]
# ## Первоначальный обход графа

# %%
# Функция присваивания весов ребрам графа
def distance_attr(G, start, dataframe):
    
    #######################################################################
    # Цикл удаления вершин, не имеющих связей и присваивания весов ребрам #
    #######################################################################    
    # Список со всеми вершинами, до которых можно добраться из точки start
    # при помощи поиска в ширину
    vert_list = list(nx.bfs_successors(G, source=start))
    # Одна из самых удаленных вершин в графе (это необходимо будет для A*)
    last_vertex = vert_list[-1][-1][0]
    
    for component in vert_list:
        vertex = component[0]  # Вершина в которой находимся на данной итерации
        neighbors = component[1]  # Вершины, которые являются соседними (которые мы еще не посещали)
        
        attrs = {vertex: {'component' : 1}}
        nx.set_node_attributes(G, attrs)
        
        print('Вершина, в которой находимся:', vertex)
        print('Прямые потомки:', neighbors)
        for n in neighbors:
            attrs = {n: {'component' : 1}}
            nx.set_node_attributes(G, attrs)
            
            # Присваиваем веса на ребра графа
            # Значение протяженности участка в метрах (int)
            try:
                dist_n = int(dataframe['length'][dataframe['id'] == n])
                attrs = {(vertex, n): {'weight': dist_n},
                         (n, vertex): {'weight': dist_n}}
                nx.set_edge_attributes(G, attrs)
            except Exception:
                pass
            
        # Осматриваем окрестности вершины в которой находимся
        offspring = list(nx.bfs_successors(G, source = vertex, depth_limit = 1)) 
        offspring = offspring[0][1]
        # Если значение веса не было присвоено - присваиваем его
        for n in offspring:
            
            print(vertex, ' - ', n, G.get_edge_data(vertex, n))
            print(vertex, ' - ', n, G.get_edge_data(n, vertex))
            
            if len(G.get_edge_data(vertex, n)) == 0:
                dist_n = int(dataframe['length'][dataframe['id'] == n])
                attrs = {(vertex, n): {'weight': dist_n},
                         (n, vertex): {'weight': dist_n}}
                nx.set_edge_attributes(G, attrs)
            elif len(G.get_edge_data(n, vertex)) == 0:
                dist_n = int(dataframe['length'][dataframe['id'] == n])
                attrs = {(vertex, n): {'weight': dist_n},
                         (n, vertex): {'weight': dist_n}}
                nx.set_edge_attributes(G, attrs)
                
                
                
            # Дообход графа    
            N_offspring = list(nx.bfs_successors(G, source = n, depth_limit = 1))
            N_offspring = N_offspring[0][1]            
            for N in N_offspring:
                if len(G.get_edge_data(n, N)) == 0:
                    dist_n = int(dataframe['length'][dataframe['id'] == N])
                    attrs = {(n, N): {'weight': dist_n},
                             (N, n): {'weight': dist_n}}
                    nx.set_edge_attributes(G, attrs)
                elif len(G.get_edge_data(N, n)) == 0:
                    dist_n = int(dataframe['length'][dataframe['id'] == N])
                    attrs = {(N, n): {'weight': dist_n},
                             (n, N): {'weight': dist_n}}
                    nx.set_edge_attributes(G, attrs)
                
        
        print('\n')
        
    for vertex in list(G.nodes()):
        # Если граф неполносвязный, то удаляем те элементы, до которых мы не можем добраться
        if G.nodes[vertex].get('component') == None:
            G.remove_node(vertex)
        else:
            pass

    #######################################################################
    # Цикл удаления вершин, не имеющих связей и присваивания весов ребрам #
    #######################################################################
    
    #####################################################
    # Цикл удаления побочных ребер в образованном графе #
    #####################################################
    #vert_list = list(nx.bfs_successors(G, source=start))
    #for component in vert_list:
    #    vertex = component[0]  # Вершина в которой находимся на данной итерации
    #    neighbors = component[1]  # Вершины, которые являются соседними (которые мы еще не посещали)
    #
    #    # Блок удаления побочных связей между узлами
    #    if len(neighbors) > 1:
    #        for n1 in neighbors:
    #            for n2 in neighbors:
    #                try:
    #                    G.remove_edge(n1, n2)
    #                except Exception:
    #                    pass
    #####################################################
    # Цикл удаления побочных ребер в образованном графе #
    #####################################################
    
    return(last_vertex)    

# Применение алгоритма
last_vertex = distance_attr(G, 293, dataframe)
# Out:
# Вершина, в которой находимся: 293
# Прямые потомки: [48, 321]
# 293  -  48 {'weight': 7829}
# 293  -  48 {'weight': 7829}
# 293  -  321 {'weight': 7970}
# 293  -  321 {'weight': 7970}
#
#
# Вершина, в которой находимся: 48
# Прямые потомки: [49, 151]
# 48  -  49 {'weight': 17260}
# 48  -  49 {'weight': 17260}
# 48  -  151 {'weight': 14613}
# 48  -  151 {'weight': 14613}
# 48  -  293 {'weight': 7829}
# 48  -  293 {'weight': 7829}
# 48  -  321 {'weight': 7970}
# 48  -  321 {'weight': 7970}
#
#
# Вершина, в которой находимся: 321
# Прямые потомки: [320]
# 321  -  48 {'weight': 7970}
# 321  -  48 {'weight': 7970}
# 321  -  151 {'weight': 14613}
# 321  -  151 {'weight': 14613}
# 321  -  293 {'weight': 7970}
# 321  -  293 {'weight': 7970}
# 321  -  320 {'weight': 2860}
# 321  -  320 {'weight': 2860}
#
#
# Вершина, в которой находимся: 49
# Прямые потомки: [50, 262]
# 49  -  48 {'weight': 17260}
# 49  -  48 {'weight': 17260}
# 49  -  50 {'weight': 4677}
# 49  -  50 {'weight': 4677}
# 49  -  151 {'weight': 14613}
# 49  -  151 {'weight': 14613}
# 49  -  262 {'weight': 41902}
# 49  -  262 {'weight': 41902}
#
#
# Вершина, в которой находимся: 320
# Прямые потомки: [99, 327]
# 320  -  99 {'weight': 18968}
# 320  -  99 {'weight': 18968}
# 320  -  151 {'weight': 2860}
# 320  -  151 {'weight': 2860}
# 320  -  321 {'weight': 2860}
# 320  -  321 {'weight': 2860}
# 320  -  327 {'weight': 38690}
# 320  -  327 {'weight': 38690}
#
#
# Вершина, в которой находимся: 50
# Прямые потомки: [51, 139]
# 50  -  49 {'weight': 4677}
# 50  -  49 {'weight': 4677}
# 50  -  51 {'weight': 49969}
# 50  -  51 {'weight': 49969}
# 50  -  139 {'weight': 60363}
# 50  -  139 {'weight': 60363}
# 50  -  262 {'weight': 41902}
# 50  -  262 {'weight': 41902}
#
#
# Вершина, в которой находимся: 262
# Прямые потомки: [41, 44]
# 262  -  41 {'weight': 14602}
# 262  -  41 {'weight': 14602}
# 262  -  44 {'weight': 23546}
# 262  -  44 {'weight': 23546}
# 262  -  49 {'weight': 41902}
# 262  -  49 {'weight': 41902}
# 262  -  50 {'weight': 41902}
# 262  -  50 {'weight': 41902}
#
#
# Вершина, в которой находимся: 99
# Прямые потомки: [101, 102]
# 99  -  101 {'weight': 12447}
# 99  -  101 {'weight': 12447}
# 99  -  102 {'weight': 25598}
# 99  -  102 {'weight': 25598}
# 99  -  320 {'weight': 18968}
# 99  -  320 {'weight': 18968}
# 99  -  327 {'weight': 38690}
# 99  -  327 {'weight': 38690}
#
#
# Вершина, в которой находимся: 327
# Прямые потомки: [152, 326]
# 327  -  99 {'weight': 38690}
# 327  -  99 {'weight': 38690}
# 327  -  152 {'weight': 33626}
# 327  -  152 {'weight': 33626}
# 327  -  320 {'weight': 38690}
# 327  -  320 {'weight': 38690}
# 327  -  326 {'weight': 10102}
# 327  -  326 {'weight': 10102}
#
#
# Вершина, в которой находимся: 51
# Прямые потомки: [45]
# 51  -  44 {'weight': 23546}
# 51  -  44 {'weight': 23546}
# 51  -  45 {'weight': 33955}
# 51  -  45 {'weight': 33955}
# 51  -  50 {'weight': 49969}
# 51  -  50 {'weight': 49969}
# 51  -  139 {'weight': 60363}
# 51  -  139 {'weight': 60363}
#
#
# Вершина, в которой находимся: 139
# Прямые потомки: [325]
# 139  -  50 {'weight': 60363}
# 139  -  50 {'weight': 60363}
# 139  -  51 {'weight': 60363}
# 139  -  51 {'weight': 60363}
# 139  -  325 {'weight': 916}
# 139  -  325 {'weight': 916}
# 139  -  326 {'weight': 10102}
# 139  -  326 {'weight': 10102}
#
#
# Вершина, в которой находимся: 41
# Прямые потомки: [43]
# 41  -  43 {'weight': 48784}
# 41  -  43 {'weight': 48784}
# 41  -  44 {'weight': 23546}
# 41  -  44 {'weight': 23546}
# 41  -  262 {'weight': 14602}
# 41  -  262 {'weight': 14602}
#
#
# Вершина, в которой находимся: 101
# Прямые потомки: [100]
# 101  -  99 {'weight': 12447}
# 101  -  99 {'weight': 12447}
# 101  -  100 {'weight': 36474}
# 101  -  100 {'weight': 36474}
# 101  -  102 {'weight': 25598}
# 101  -  102 {'weight': 25598}
# 101  -  152 {'weight': 33626}
# 101  -  152 {'weight': 33626}
#
#
# Вершина, в которой находимся: 102
# Прямые потомки: [103, 366]
# 102  -  99 {'weight': 25598}
# 102  -  99 {'weight': 25598}
# 102  -  101 {'weight': 25598}
# 102  -  101 {'weight': 25598}
# 102  -  103 {'weight': 20817}
# 102  -  103 {'weight': 20817}
# 102  -  366 {'weight': 9222}
# 102  -  366 {'weight': 9222}
#
#
# Вершина, в которой находимся: 45
# Прямые потомки: [319, 322]
# 45  -  44 {'weight': 33955}
# 45  -  44 {'weight': 33955}
# 45  -  51 {'weight': 33955}
# 45  -  51 {'weight': 33955}
# 45  -  319 {'weight': 13003}
# 45  -  319 {'weight': 13003}
# 45  -  322 {'weight': 14271}
# 45  -  322 {'weight': 14271}
#
#
# Вершина, в которой находимся: 325
# Прямые потомки: [153, 324]
# 325  -  139 {'weight': 916}
# 325  -  139 {'weight': 916}
# 325  -  153 {'weight': 21337}
# 325  -  153 {'weight': 21337}
# 325  -  324 {'weight': 2256}
# 325  -  324 {'weight': 2256}
# 325  -  326 {'weight': 916}
# 325  -  326 {'weight': 916}
#
#
# Вершина, в которой находимся: 43
# Прямые потомки: [42, 362]
# 43  -  41 {'weight': 48784}
# 43  -  41 {'weight': 48784}
# 43  -  42 {'weight': 52282}
# 43  -  42 {'weight': 52282}
# 43  -  362 {'weight': 62571}
# 43  -  362 {'weight': 62571}
#
#
# Вершина, в которой находимся: 319
# Прямые потомки: [154, 318]
# 319  -  45 {'weight': 13003}
# 319  -  45 {'weight': 13003}
# 319  -  154 {'weight': 39118}
# 319  -  154 {'weight': 39118}
# 319  -  318 {'weight': 15712}
# 319  -  318 {'weight': 15712}
# 319  -  322 {'weight': 14271}
# 319  -  322 {'weight': 14271}
#
#
# Вершина, в которой находимся: 322
# Прямые потомки: [323]
# 322  -  45 {'weight': 14271}
# 322  -  45 {'weight': 14271}
# 322  -  153 {'weight': 21337}
# 322  -  153 {'weight': 21337}
# 322  -  319 {'weight': 14271}
# 322  -  319 {'weight': 14271}
# 322  -  323 {'weight': 13331}
# 322  -  323 {'weight': 13331}
#
#
# Вершина, в которой находимся: 324
# Прямые потомки: [136]
# 324  -  136 {'weight': 48643}
# 324  -  136 {'weight': 48643}
# 324  -  153 {'weight': 2256}
# 324  -  153 {'weight': 2256}
# 324  -  323 {'weight': 13331}
# 324  -  323 {'weight': 13331}
# 324  -  325 {'weight': 2256}
# 324  -  325 {'weight': 2256}
#
#
# Вершина, в которой находимся: 42
# Прямые потомки: [294]
# 42  -  43 {'weight': 52282}
# 42  -  43 {'weight': 52282}
# 42  -  294 {'weight': 48464}
# 42  -  294 {'weight': 48464}
# 42  -  318 {'weight': 15712}
# 42  -  318 {'weight': 15712}
# 42  -  362 {'weight': 62571}
# 42  -  362 {'weight': 62571}
#
#
# Вершина, в которой находимся: 136
# Прямые потомки: [144, 148]
# 136  -  144 {'weight': 13824}
# 136  -  144 {'weight': 13824}
# 136  -  148 {'weight': 4814}
# 136  -  148 {'weight': 4814}
# 136  -  323 {'weight': 48643}
# 136  -  323 {'weight': 48643}
# 136  -  324 {'weight': 48643}
# 136  -  324 {'weight': 48643}
#
#
# Вершина, в которой находимся: 294
# Прямые потомки: [297, 379]
# 294  -  42 {'weight': 48464}
# 294  -  42 {'weight': 48464}
# 294  -  297 {'weight': 12854}
# 294  -  297 {'weight': 12854}
# 294  -  318 {'weight': 48464}
# 294  -  318 {'weight': 48464}
# 294  -  379 {'weight': 26387}
# 294  -  379 {'weight': 26387}
#
#
# Вершина, в которой находимся: 297
# Прямые потомки: [135, 296]
# 297  -  135 {'weight': 13259}
# 297  -  135 {'weight': 13259}
# 297  -  294 {'weight': 12854}
# 297  -  294 {'weight': 12854}
# 297  -  296 {'weight': 48805}
# 297  -  296 {'weight': 48805}
# 297  -  379 {'weight': 26387}
# 297  -  379 {'weight': 26387}
#
#
# Вершина, в которой находимся: 379
# Прямые потомки: [338, 378]
# 379  -  294 {'weight': 26387}
# 379  -  294 {'weight': 26387}
# 379  -  297 {'weight': 26387}
# 379  -  297 {'weight': 26387}
# 379  -  338 {'weight': 81199}
# 379  -  338 {'weight': 81199}
# 379  -  378 {'weight': 38118}
# 379  -  378 {'weight': 38118}
#
#
# Вершина, в которой находимся: 135
# Прямые потомки: [142, 259]
# 135  -  142 {'weight': 66581}
# 135  -  142 {'weight': 66581}
# 135  -  259 {'weight': 8691}
# 135  -  259 {'weight': 8691}
# 135  -  296 {'weight': 48805}
# 135  -  296 {'weight': 48805}
# 135  -  297 {'weight': 13259}
# 135  -  297 {'weight': 13259}
#
#
# Вершина, в которой находимся: 296
# Прямые потомки: [308]
# 296  -  135 {'weight': 48805}
# 296  -  135 {'weight': 48805}
# 296  -  297 {'weight': 48805}
# 296  -  297 {'weight': 48805}
# 296  -  308 {'weight': 1180}
# 296  -  308 {'weight': 1180}
# 296  -  338 {'weight': 81199}
# 296  -  338 {'weight': 81199}
#
#
# Вершина, в которой находимся: 378
# Прямые потомки: [248]
# 378  -  248 {'weight': 38886}
# 378  -  248 {'weight': 38886}
# 378  -  338 {'weight': 38118}
# 378  -  338 {'weight': 38118}
# 378  -  379 {'weight': 38118}
# 378  -  379 {'weight': 38118}
#
#
# Вершина, в которой находимся: 142
# Прямые потомки: [143, 160]
# 142  -  135 {'weight': 66581}
# 142  -  135 {'weight': 66581}
# 142  -  143 {'weight': 2470}
# 142  -  143 {'weight': 2470}
# 142  -  160 {'weight': 17586}
# 142  -  160 {'weight': 17586}
# 142  -  259 {'weight': 8691}
# 142  -  259 {'weight': 8691}
#
#
# Вершина, в которой находимся: 308
# Прямые потомки: [185, 307]
# 308  -  185 {'weight': 77931}
# 308  -  185 {'weight': 77931}
# 308  -  296 {'weight': 1180}
# 308  -  296 {'weight': 1180}
# 308  -  307 {'weight': 384079}
# 308  -  307 {'weight': 384079}
# 308  -  338 {'weight': 1180}
# 308  -  338 {'weight': 1180}
#
#
# Вершина, в которой находимся: 185
# Прямые потомки: [137, 184]
# 185  -  137 {'weight': 6543}
# 185  -  137 {'weight': 6543}
# 185  -  184 {'weight': 45060}
# 185  -  184 {'weight': 45060}
# 185  -  307 {'weight': 384079}
# 185  -  307 {'weight': 384079}
# 185  -  308 {'weight': 77931}
# 185  -  308 {'weight': 77931}
#
#
# Вершина, в которой находимся: 307
# Прямые потомки: [306, 351]
# 307  -  185 {'weight': 384079}
# 307  -  185 {'weight': 384079}
# 307  -  306 {'weight': 42339}
# 307  -  306 {'weight': 42339}
# 307  -  308 {'weight': 384079}
# 307  -  308 {'weight': 384079}
# 307  -  351 {'weight': 14731}
# 307  -  351 {'weight': 14731}
#
#
# Вершина, в которой находимся: 137
# Прямые потомки: [115, 117]
# 137  -  115 {'weight': 104219}
# 137  -  115 {'weight': 104219}
# 137  -  117 {'weight': 89958}
# 137  -  117 {'weight': 89958}
# 137  -  184 {'weight': 45060}
# 137  -  184 {'weight': 45060}
# 137  -  185 {'weight': 6543}
# 137  -  185 {'weight': 6543}
#
#
# Вершина, в которой находимся: 184
# Прямые потомки: [114]
# 184  -  114 {'weight': 72489}
# 184  -  114 {'weight': 72489}
# 184  -  137 {'weight': 45060}
# 184  -  137 {'weight': 45060}
# 184  -  185 {'weight': 45060}
# 184  -  185 {'weight': 45060}
#
#
# Вершина, в которой находимся: 306
# Прямые потомки: [186, 305]
# 306  -  186 {'weight': 64986}
# 306  -  186 {'weight': 64986}
# 306  -  305 {'weight': 19786}
# 306  -  305 {'weight': 19786}
# 306  -  307 {'weight': 42339}
# 306  -  307 {'weight': 42339}
# 306  -  351 {'weight': 14731}
# 306  -  351 {'weight': 14731}
#
#
# Вершина, в которой находимся: 351
# Прямые потомки: [395, 396]
# 351  -  306 {'weight': 14731}
# 351  -  306 {'weight': 14731}
# 351  -  307 {'weight': 14731}
# 351  -  307 {'weight': 14731}
# 351  -  395 {'weight': 16449}
# 351  -  395 {'weight': 16449}
# 351  -  396 {'weight': 7317}
# 351  -  396 {'weight': 7317}
#
#
# Вершина, в которой находимся: 115
# Прямые потомки: [28, 116]
# 115  -  28 {'weight': 19722}
# 115  -  28 {'weight': 19722}
# 115  -  116 {'weight': 15776}
# 115  -  116 {'weight': 15776}
# 115  -  117 {'weight': 89958}
# 115  -  117 {'weight': 89958}
# 115  -  137 {'weight': 104219}
# 115  -  137 {'weight': 104219}
#
#
# Вершина, в которой находимся: 117
# Прямые потомки: [145]
# 117  -  115 {'weight': 89958}
# 117  -  115 {'weight': 89958}
# 117  -  116 {'weight': 15776}
# 117  -  116 {'weight': 15776}
# 117  -  137 {'weight': 89958}
# 117  -  137 {'weight': 89958}
# 117  -  145 {'weight': 12713}
# 117  -  145 {'weight': 12713}
#
#
# Вершина, в которой находимся: 114
# Прямые потомки: [113]
# 114  -  113 {'weight': 92580}
# 114  -  113 {'weight': 92580}
# 114  -  145 {'weight': 12713}
# 114  -  145 {'weight': 12713}
# 114  -  184 {'weight': 72489}
# 114  -  184 {'weight': 72489}
#
#
# Вершина, в которой находимся: 186
# Прямые потомки: [7]
# 186  -  7 {'weight': 10124}
# 186  -  7 {'weight': 10124}
# 186  -  305 {'weight': 19786}
# 186  -  305 {'weight': 19786}
# 186  -  306 {'weight': 64986}
# 186  -  306 {'weight': 64986}
#
#
# Вершина, в которой находимся: 305
# Прямые потомки: [290, 368]
# 305  -  186 {'weight': 19786}
# 305  -  186 {'weight': 19786}
# 305  -  290 {'weight': 68737}
# 305  -  290 {'weight': 68737}
# 305  -  306 {'weight': 19786}
# 305  -  306 {'weight': 19786}
# 305  -  368 {'weight': 7452}
# 305  -  368 {'weight': 7452}
#
#
# Вершина, в которой находимся: 395
# Прямые потомки: [167, 352]
# 395  -  167 {'weight': 4461}
# 395  -  167 {'weight': 4461}
# 395  -  351 {'weight': 16449}
# 395  -  351 {'weight': 16449}
# 395  -  352 {'weight': 80602}
# 395  -  352 {'weight': 80602}
# 395  -  396 {'weight': 7317}
# 395  -  396 {'weight': 7317}
#
#
# Вершина, в которой находимся: 396
# Прямые потомки: [166]
# 396  -  166 {'weight': 7145}
# 396  -  166 {'weight': 7145}
# 396  -  351 {'weight': 7317}
# 396  -  351 {'weight': 7317}
# 396  -  395 {'weight': 7317}
# 396  -  395 {'weight': 7317}
#
#
# Вершина, в которой находимся: 28
# Прямые потомки: [354, 355]
# 28  -  115 {'weight': 19722}
# 28  -  115 {'weight': 19722}
# 28  -  116 {'weight': 15776}
# 28  -  116 {'weight': 15776}
# 28  -  354 {'weight': 4030}
# 28  -  354 {'weight': 4030}
# 28  -  355 {'weight': 96686}
# 28  -  355 {'weight': 96686}
#
#
# Вершина, в которой находимся: 290
# Прямые потомки: [264, 289]
# 290  -  264 {'weight': 17103}
# 290  -  264 {'weight': 17103}
# 290  -  289 {'weight': 9672}
# 290  -  289 {'weight': 9672}
# 290  -  305 {'weight': 68737}
# 290  -  305 {'weight': 68737}
# 290  -  368 {'weight': 7452}
# 290  -  368 {'weight': 7452}
#
#
# Вершина, в которой находимся: 368
# Прямые потомки: [245, 369]
# 368  -  245 {'weight': 114576}
# 368  -  245 {'weight': 114576}
# 368  -  290 {'weight': 7452}
# 368  -  290 {'weight': 7452}
# 368  -  305 {'weight': 7452}
# 368  -  305 {'weight': 7452}
# 368  -  369 {'weight': 54638}
# 368  -  369 {'weight': 54638}
#
#
# Вершина, в которой находимся: 352
# Прямые потомки: [400, 401]
# 352  -  167 {'weight': 80602}
# 352  -  167 {'weight': 80602}
# 352  -  395 {'weight': 80602}
# 352  -  395 {'weight': 80602}
# 352  -  400 {'weight': 1319}
# 352  -  400 {'weight': 1319}
# 352  -  401 {'weight': 11011}
# 352  -  401 {'weight': 11011}
#
#
# Вершина, в которой находимся: 354
# Прямые потомки: [403, 404]
# 354  -  28 {'weight': 4030}
# 354  -  28 {'weight': 4030}
# 354  -  355 {'weight': 96686}
# 354  -  355 {'weight': 96686}
# 354  -  403 {'weight': 21020}
# 354  -  403 {'weight': 21020}
# 354  -  404 {'weight': 18258}
# 354  -  404 {'weight': 18258}
#
#
# Вершина, в которой находимся: 355
# Прямые потомки: [409, 410]
# 355  -  28 {'weight': 96686}
# 355  -  28 {'weight': 96686}
# 355  -  354 {'weight': 96686}
# 355  -  354 {'weight': 96686}
# 355  -  409 {'weight': 4779}
# 355  -  409 {'weight': 4779}
# 355  -  410 {'weight': 2725}
# 355  -  410 {'weight': 2725}
#
#
# Вершина, в которой находимся: 264
# Прямые потомки: [350]
# 264  -  289 {'weight': 9672}
# 264  -  289 {'weight': 9672}
# 264  -  290 {'weight': 17103}
# 264  -  290 {'weight': 17103}
# 264  -  350 {'weight': 4697}
# 264  -  350 {'weight': 4697}
#
#
# Вершина, в которой находимся: 289
# Прямые потомки: [265, 291]
# 289  -  264 {'weight': 9672}
# 289  -  264 {'weight': 9672}
# 289  -  265 {'weight': 28102}
# 289  -  265 {'weight': 28102}
# 289  -  290 {'weight': 9672}
# 289  -  290 {'weight': 9672}
# 289  -  291 {'weight': 6872}
# 289  -  291 {'weight': 6872}
#
#
# Вершина, в которой находимся: 369
# Прямые потомки: [60, 371]
# 369  -  60 {'weight': 18083}
# 369  -  60 {'weight': 18083}
# 369  -  245 {'weight': 54638}
# 369  -  245 {'weight': 54638}
# 369  -  368 {'weight': 54638}
# 369  -  368 {'weight': 54638}
# 369  -  371 {'weight': 18266}
# 369  -  371 {'weight': 18266}
#
#
# Вершина, в которой находимся: 400
# Прямые потомки: [402]
# 400  -  352 {'weight': 1319}
# 400  -  352 {'weight': 1319}
# 400  -  401 {'weight': 11011}
# 400  -  401 {'weight': 11011}
# 400  -  402 {'weight': 8921}
# 400  -  402 {'weight': 8921}
#
#
# Вершина, в которой находимся: 401
# Прямые потомки: [353]
# 401  -  352 {'weight': 11011}
# 401  -  352 {'weight': 11011}
# 401  -  353 {'weight': 25821}
# 401  -  353 {'weight': 25821}
# 401  -  400 {'weight': 11011}
# 401  -  400 {'weight': 11011}
# 401  -  402 {'weight': 8921}
# 401  -  402 {'weight': 8921}
#
#
# Вершина, в которой находимся: 403
# Прямые потомки: [168]
# 403  -  168 {'weight': 3027}
# 403  -  168 {'weight': 3027}
# 403  -  353 {'weight': 25821}
# 403  -  353 {'weight': 25821}
# 403  -  354 {'weight': 21020}
# 403  -  354 {'weight': 21020}
# 403  -  404 {'weight': 18258}
# 403  -  404 {'weight': 18258}
#
#
# Вершина, в которой находимся: 409
# Прямые потомки: [111, 170]
# 409  -  111 {'weight': 9660}
# 409  -  111 {'weight': 9660}
# 409  -  170 {'weight': 4237}
# 409  -  170 {'weight': 4237}
# 409  -  355 {'weight': 4779}
# 409  -  355 {'weight': 4779}
# 409  -  410 {'weight': 2725}
# 409  -  410 {'weight': 2725}
#
#
# Вершина, в которой находимся: 410
# Прямые потомки: [169]
# 410  -  169 {'weight': 1969}
# 410  -  169 {'weight': 1969}
# 410  -  355 {'weight': 2725}
# 410  -  355 {'weight': 2725}
# 410  -  409 {'weight': 2725}
# 410  -  409 {'weight': 2725}
#
#
# Вершина, в которой находимся: 350
# Прямые потомки: [389, 390]
# 350  -  264 {'weight': 4697}
# 350  -  264 {'weight': 4697}
# 350  -  389 {'weight': 3318}
# 350  -  389 {'weight': 3318}
# 350  -  390 {'weight': 3042}
# 350  -  390 {'weight': 3042}
#
#
# Вершина, в которой находимся: 265
# Прямые потомки: [22, 23]
# 265  -  22 {'weight': 26422}
# 265  -  22 {'weight': 26422}
# 265  -  23 {'weight': 25027}
# 265  -  23 {'weight': 25027}
# 265  -  289 {'weight': 28102}
# 265  -  289 {'weight': 28102}
# 265  -  291 {'weight': 6872}
# 265  -  291 {'weight': 6872}
#
#
# Вершина, в которой находимся: 291
# Прямые потомки: [266, 295]
# 291  -  265 {'weight': 6872}
# 291  -  265 {'weight': 6872}
# 291  -  266 {'weight': 28657}
# 291  -  266 {'weight': 28657}
# 291  -  289 {'weight': 6872}
# 291  -  289 {'weight': 6872}
# 291  -  295 {'weight': 47963}
# 291  -  295 {'weight': 47963}
#
#
# Вершина, в которой находимся: 371
# Прямые потомки: [64, 370]
# 371  -  60 {'weight': 18266}
# 371  -  60 {'weight': 18266}
# 371  -  64 {'weight': 32241}
# 371  -  64 {'weight': 32241}
# 371  -  369 {'weight': 18266}
# 371  -  369 {'weight': 18266}
# 371  -  370 {'weight': 50059}
# 371  -  370 {'weight': 50059}
#
#
# Вершина, в которой находимся: 111
# Прямые потомки: [412, 413]
# 111  -  170 {'weight': 4237}
# 111  -  170 {'weight': 4237}
# 111  -  409 {'weight': 9660}
# 111  -  409 {'weight': 9660}
# 111  -  412 {'weight': 1209}
# 111  -  412 {'weight': 1209}
# 111  -  413 {'weight': 2429}
# 111  -  413 {'weight': 2429}
#
#
# Вершина, в которой находимся: 170
# Прямые потомки: [6]
# 170  -  6 {'weight': 9908}
# 170  -  6 {'weight': 9908}
# 170  -  111 {'weight': 4237}
# 170  -  111 {'weight': 4237}
# 170  -  169 {'weight': 1969}
# 170  -  169 {'weight': 1969}
# 170  -  409 {'weight': 4237}
# 170  -  409 {'weight': 4237}
#
#
# Вершина, в которой находимся: 389
# Прямые потомки: [110]
# 389  -  110 {'weight': 1265}
# 389  -  110 {'weight': 1265}
# 389  -  350 {'weight': 3318}
# 389  -  350 {'weight': 3318}
# 389  -  390 {'weight': 3042}
# 389  -  390 {'weight': 3042}
#
#
# Вершина, в которой находимся: 266
# Прямые потомки: [24, 250]
# 266  -  24 {'weight': 30723}
# 266  -  24 {'weight': 30723}
# 266  -  250 {'weight': 29905}
# 266  -  250 {'weight': 29905}
# 266  -  291 {'weight': 28657}
# 266  -  291 {'weight': 28657}
# 266  -  295 {'weight': 47963}
# 266  -  295 {'weight': 47963}
#
#
# Вершина, в которой находимся: 295
# Прямые потомки: [61, 310]
# 295  -  61 {'weight': 41375}
# 295  -  61 {'weight': 41375}
# 295  -  266 {'weight': 47963}
# 295  -  266 {'weight': 47963}
# 295  -  291 {'weight': 47963}
# 295  -  291 {'weight': 47963}
# 295  -  310 {'weight': 9357}
# 295  -  310 {'weight': 9357}
#
#
# Вершина, в которой находимся: 64
# Прямые потомки: [63, 95]
# 64  -  63 {'weight': 17562}
# 64  -  63 {'weight': 17562}
# 64  -  95 {'weight': 17915}
# 64  -  95 {'weight': 17915}
# 64  -  370 {'weight': 50059}
# 64  -  370 {'weight': 50059}
# 64  -  371 {'weight': 32241}
# 64  -  371 {'weight': 32241}
#
#
# Вершина, в которой находимся: 370
# Прямые потомки: [263, 367]
# 370  -  64 {'weight': 50059}
# 370  -  64 {'weight': 50059}
# 370  -  263 {'weight': 26042}
# 370  -  263 {'weight': 26042}
# 370  -  367 {'weight': 21220}
# 370  -  367 {'weight': 21220}
# 370  -  371 {'weight': 50059}
# 370  -  371 {'weight': 50059}
#
#
# Вершина, в которой находимся: 412
# Прямые потомки: [415]
# 412  -  111 {'weight': 1209}
# 412  -  111 {'weight': 1209}
# 412  -  413 {'weight': 2429}
# 412  -  413 {'weight': 2429}
# 412  -  415 {'weight': 3025}
# 412  -  415 {'weight': 3025}
#
#
# Вершина, в которой находимся: 413
# Прямые потомки: [146, 414]
# 413  -  111 {'weight': 2429}
# 413  -  111 {'weight': 2429}
# 413  -  146 {'weight': 3652}
# 413  -  146 {'weight': 3652}
# 413  -  412 {'weight': 2429}
# 413  -  412 {'weight': 2429}
# 413  -  414 {'weight': 4369}
# 413  -  414 {'weight': 4369}
#
#
# Вершина, в которой находимся: 6
# Прямые потомки: [180, 436]
# 6  -  169 {'weight': 9908}
# 6  -  169 {'weight': 9908}
# 6  -  170 {'weight': 9908}
# 6  -  170 {'weight': 9908}
# 6  -  180 {'weight': 10358}
# 6  -  180 {'weight': 10358}
# 6  -  436 {'weight': 11696}
# 6  -  436 {'weight': 11696}
#
#
# Вершина, в которой находимся: 110
# Прямые потомки: [387, 388]
# 110  -  387 {'weight': 3597}
# 110  -  387 {'weight': 3597}
# 110  -  388 {'weight': 3213}
# 110  -  388 {'weight': 3213}
# 110  -  389 {'weight': 1265}
# 110  -  389 {'weight': 1265}
# 110  -  390 {'weight': 1265}
# 110  -  390 {'weight': 1265}
#
#
# Вершина, в которой находимся: 310
# Прямые потомки: [209, 309]
# 310  -  61 {'weight': 9357}
# 310  -  61 {'weight': 9357}
# 310  -  209 {'weight': 21556}
# 310  -  209 {'weight': 21556}
# 310  -  295 {'weight': 9357}
# 310  -  295 {'weight': 9357}
# 310  -  309 {'weight': 2520}
# 310  -  309 {'weight': 2520}
#
#
# Вершина, в которой находимся: 263
# Прямые потомки: [20]
# 263  -  20 {'weight': 9791}
# 263  -  20 {'weight': 9791}
# 263  -  367 {'weight': 21220}
# 263  -  367 {'weight': 21220}
# 263  -  370 {'weight': 26042}
# 263  -  370 {'weight': 26042}
#
#
# Вершина, в которой находимся: 367
# Прямые потомки: [15, 149]
# 367  -  15 {'weight': 22463}
# 367  -  15 {'weight': 22463}
# 367  -  149 {'weight': 21747}
# 367  -  149 {'weight': 21747}
# 367  -  263 {'weight': 21220}
# 367  -  263 {'weight': 21220}
# 367  -  370 {'weight': 21220}
# 367  -  370 {'weight': 21220}
#
#
# Вершина, в которой находимся: 415
# Прямые потомки: [112]
# 415  -  112 {'weight': 727}
# 415  -  112 {'weight': 727}
# 415  -  412 {'weight': 3025}
# 415  -  412 {'weight': 3025}
# 415  -  414 {'weight': 4369}
# 415  -  414 {'weight': 4369}
#
#
# Вершина, в которой находимся: 146
# Прямые потомки: [439, 440]
# 146  -  413 {'weight': 3652}
# 146  -  413 {'weight': 3652}
# 146  -  414 {'weight': 4369}
# 146  -  414 {'weight': 4369}
# 146  -  439 {'weight': 3719}
# 146  -  439 {'weight': 3719}
# 146  -  440 {'weight': 1941}
# 146  -  440 {'weight': 1941}
#
#
# Вершина, в которой находимся: 387
# Прямые потомки: [109]
# 387  -  109 {'weight': 1736}
# 387  -  109 {'weight': 1736}
# 387  -  110 {'weight': 3597}
# 387  -  110 {'weight': 3597}
# 387  -  388 {'weight': 3213}
# 387  -  388 {'weight': 3213}
#
#
# Вершина, в которой находимся: 209
# Прямые потомки: [399]
# 209  -  309 {'weight': 2520}
# 209  -  309 {'weight': 2520}
# 209  -  310 {'weight': 21556}
# 209  -  310 {'weight': 21556}
# 209  -  399 {'weight': 2649}
# 209  -  399 {'weight': 2649}
#
#
# Вершина, в которой находимся: 309
# Прямые потомки: [188, 304]
# 309  -  188 {'weight': 19182}
# 309  -  188 {'weight': 19182}
# 309  -  209 {'weight': 2520}
# 309  -  209 {'weight': 2520}
# 309  -  304 {'weight': 9793}
# 309  -  304 {'weight': 9793}
# 309  -  310 {'weight': 2520}
# 309  -  310 {'weight': 2520}
#
#
# Вершина, в которой находимся: 112
# Прямые потомки: [393, 394]
# 112  -  393 {'weight': 4546}
# 112  -  393 {'weight': 4546}
# 112  -  394 {'weight': 994}
# 112  -  394 {'weight': 994}
# 112  -  414 {'weight': 727}
# 112  -  414 {'weight': 727}
# 112  -  415 {'weight': 727}
# 112  -  415 {'weight': 727}
#
#
# Вершина, в которой находимся: 439
# Прямые потомки: [183]
# 439  -  146 {'weight': 3719}
# 439  -  146 {'weight': 3719}
# 439  -  183 {'weight': 426}
# 439  -  183 {'weight': 426}
# 439  -  440 {'weight': 1941}
# 439  -  440 {'weight': 1941}
#
#
# Вершина, в которой находимся: 440
# Прямые потомки: [147]
# 440  -  146 {'weight': 1941}
# 440  -  146 {'weight': 1941}
# 440  -  147 {'weight': 559}
# 440  -  147 {'weight': 559}
# 440  -  183 {'weight': 426}
# 440  -  183 {'weight': 426}
# 440  -  439 {'weight': 1941}
# 440  -  439 {'weight': 1941}
#
#
# Вершина, в которой находимся: 109
# Прямые потомки: [21, 108]
# 109  -  21 {'weight': 24385}
# 109  -  21 {'weight': 24385}
# 109  -  108 {'weight': 21268}
# 109  -  108 {'weight': 21268}
# 109  -  387 {'weight': 1736}
# 109  -  387 {'weight': 1736}
# 109  -  388 {'weight': 1736}
# 109  -  388 {'weight': 1736}
#
#
# Вершина, в которой находимся: 399
# Прямые потомки: [208, 398]
# 399  -  208 {'weight': 15689}
# 399  -  208 {'weight': 15689}
# 399  -  209 {'weight': 2649}
# 399  -  209 {'weight': 2649}
# 399  -  398 {'weight': 3993}
# 399  -  398 {'weight': 3993}
#
#
# Вершина, в которой находимся: 188
# Прямые потомки: [187, 361]
# 188  -  187 {'weight': 173633}
# 188  -  187 {'weight': 173633}
# 188  -  304 {'weight': 9793}
# 188  -  304 {'weight': 9793}
# 188  -  309 {'weight': 19182}
# 188  -  309 {'weight': 19182}
# 188  -  361 {'weight': 15197}
# 188  -  361 {'weight': 15197}
#
#
# Вершина, в которой находимся: 304
# Прямые потомки: [268, 317]
# 304  -  188 {'weight': 9793}
# 304  -  188 {'weight': 9793}
# 304  -  268 {'weight': 16180}
# 304  -  268 {'weight': 16180}
# 304  -  309 {'weight': 9793}
# 304  -  309 {'weight': 9793}
# 304  -  317 {'weight': 58571}
# 304  -  317 {'weight': 58571}
#
#
# Вершина, в которой находимся: 393
# Прямые потомки: [164, 356]
# 393  -  112 {'weight': 4546}
# 393  -  112 {'weight': 4546}
# 393  -  164 {'weight': 877}
# 393  -  164 {'weight': 877}
# 393  -  356 {'weight': 12079}
# 393  -  356 {'weight': 12079}
# 393  -  394 {'weight': 994}
# 393  -  394 {'weight': 994}
#
#
# Вершина, в которой находимся: 147
# Прямые потомки: [442, 443]
# 147  -  183 {'weight': 559}
# 147  -  183 {'weight': 559}
# 147  -  440 {'weight': 559}
# 147  -  440 {'weight': 559}
# 147  -  442 {'weight': 4167}
# 147  -  442 {'weight': 4167}
# 147  -  443 {'weight': 9499}
# 147  -  443 {'weight': 9499}
#
#
# Вершина, в которой находимся: 208
# Прямые потомки: [207, 269]
# 208  -  207 {'weight': 75247}
# 208  -  207 {'weight': 75247}
# 208  -  269 {'weight': 34147}
# 208  -  269 {'weight': 34147}
# 208  -  398 {'weight': 3993}
# 208  -  398 {'weight': 3993}
# 208  -  399 {'weight': 15689}
# 208  -  399 {'weight': 15689}
#
#
# Вершина, в которой находимся: 187
# Прямые потомки: [11]
# 187  -  11 {'weight': 20099}
# 187  -  11 {'weight': 20099}
# 187  -  188 {'weight': 173633}
# 187  -  188 {'weight': 173633}
# 187  -  361 {'weight': 15197}
# 187  -  361 {'weight': 15197}
#
#
# Вершина, в которой находимся: 361
# Прямые потомки: [141]
# 361  -  141 {'weight': 39246}
# 361  -  141 {'weight': 39246}
# 361  -  187 {'weight': 15197}
# 361  -  187 {'weight': 15197}
# 361  -  188 {'weight': 15197}
# 361  -  188 {'weight': 15197}
#
#
# Вершина, в которой находимся: 268
# Прямые потомки: [251, 267]
# 268  -  251 {'weight': 82877}
# 268  -  251 {'weight': 82877}
# 268  -  267 {'weight': 102900}
# 268  -  267 {'weight': 102900}
# 268  -  304 {'weight': 16180}
# 268  -  304 {'weight': 16180}
# 268  -  317 {'weight': 58571}
# 268  -  317 {'weight': 58571}
#
#
# Вершина, в которой находимся: 317
# Прямые потомки: [240, 316]
# 317  -  240 {'weight': 7919}
# 317  -  240 {'weight': 7919}
# 317  -  268 {'weight': 58571}
# 317  -  268 {'weight': 58571}
# 317  -  304 {'weight': 58571}
# 317  -  304 {'weight': 58571}
# 317  -  316 {'weight': 71253}
# 317  -  316 {'weight': 71253}
#
#
# Вершина, в которой находимся: 356
# Прямые потомки: [391, 392]
# 356  -  391 {'weight': 4761}
# 356  -  391 {'weight': 4761}
# 356  -  392 {'weight': 5983}
# 356  -  392 {'weight': 5983}
# 356  -  393 {'weight': 12079}
# 356  -  393 {'weight': 12079}
#
#
# Вершина, в которой находимся: 442
# Прямые потомки: [365, 441]
# 442  -  147 {'weight': 4167}
# 442  -  147 {'weight': 4167}
# 442  -  365 {'weight': 17990}
# 442  -  365 {'weight': 17990}
# 442  -  441 {'weight': 3811}
# 442  -  441 {'weight': 3811}
# 442  -  443 {'weight': 9499}
# 442  -  443 {'weight': 9499}
#
#
# Вершина, в которой находимся: 269
# Прямые потомки: [59]
# 269  -  59 {'weight': 8364}
# 269  -  59 {'weight': 8364}
# 269  -  207 {'weight': 34147}
# 269  -  207 {'weight': 34147}
# 269  -  208 {'weight': 34147}
# 269  -  208 {'weight': 34147}
#
#
# Вершина, в которой находимся: 240
# Прямые потомки: [62, 239]
# 240  -  62 {'weight': 46807}
# 240  -  62 {'weight': 46807}
# 240  -  239 {'weight': 56227}
# 240  -  239 {'weight': 56227}
# 240  -  316 {'weight': 71253}
# 240  -  316 {'weight': 71253}
# 240  -  317 {'weight': 7919}
# 240  -  317 {'weight': 7919}
#
#
# Вершина, в которой находимся: 316
# Прямые потомки: [30, 299]
# 316  -  30 {'weight': 60796}
# 316  -  30 {'weight': 60796}
# 316  -  240 {'weight': 71253}
# 316  -  240 {'weight': 71253}
# 316  -  299 {'weight': 62352}
# 316  -  299 {'weight': 62352}
# 316  -  317 {'weight': 71253}
# 316  -  317 {'weight': 71253}
#
#
# Вершина, в которой находимся: 239
# Прямые потомки: [96, 238, 349]
# 239  -  62 {'weight': 56227}
# 239  -  62 {'weight': 56227}
# 239  -  96 {'weight': 16219}
# 239  -  96 {'weight': 16219}
# 239  -  238 {'weight': 8271}
# 239  -  238 {'weight': 8271}
# 239  -  240 {'weight': 56227}
# 239  -  240 {'weight': 56227}
# 239  -  349 {'weight': 2974}
# 239  -  349 {'weight': 2974}
#
#
# Вершина, в которой находимся: 299
# Прямые потомки: [76, 301]
# 299  -  30 {'weight': 62352}
# 299  -  30 {'weight': 62352}
# 299  -  76 {'weight': 71066}
# 299  -  76 {'weight': 71066}
# 299  -  301 {'weight': 47758}
# 299  -  301 {'weight': 47758}
# 299  -  316 {'weight': 62352}
# 299  -  316 {'weight': 62352}
#
#
# Вершина, в которой находимся: 238
# Прямые потомки: [92, 242]
# 238  -  92 {'weight': 37320}
# 238  -  92 {'weight': 37320}
# 238  -  239 {'weight': 8271}
# 238  -  239 {'weight': 8271}
# 238  -  242 {'weight': 55202}
# 238  -  242 {'weight': 55202}
# 238  -  349 {'weight': 2974}
# 238  -  349 {'weight': 2974}
#
#
# Вершина, в которой находимся: 349
# Прямые потомки: [254, 348]
# 349  -  96 {'weight': 2974}
# 349  -  96 {'weight': 2974}
# 349  -  238 {'weight': 2974}
# 349  -  238 {'weight': 2974}
# 349  -  239 {'weight': 2974}
# 349  -  239 {'weight': 2974}
# 349  -  254 {'weight': 13600}
# 349  -  254 {'weight': 13600}
# 349  -  348 {'weight': 26265}
# 349  -  348 {'weight': 26265}
#
#
# Вершина, в которой находимся: 301
# Прямые потомки: [77, 193, 300]
# 301  -  76 {'weight': 47758}
# 301  -  76 {'weight': 47758}
# 301  -  77 {'weight': 38154}
# 301  -  77 {'weight': 38154}
# 301  -  193 {'weight': 29917}
# 301  -  193 {'weight': 29917}
# 301  -  299 {'weight': 47758}
# 301  -  299 {'weight': 47758}
# 301  -  300 {'weight': 64385}
# 301  -  300 {'weight': 64385}
#
#
# Вершина, в которой находимся: 242
# Прямые потомки: [241, 274]
# 242  -  92 {'weight': 55202}
# 242  -  92 {'weight': 55202}
# 242  -  238 {'weight': 55202}
# 242  -  238 {'weight': 55202}
# 242  -  241 {'weight': 5416}
# 242  -  241 {'weight': 5416}
# 242  -  274 {'weight': 26938}
# 242  -  274 {'weight': 26938}
#
#
# Вершина, в которой находимся: 254
# Прямые потомки: [29]
# 254  -  29 {'weight': 23411}
# 254  -  29 {'weight': 23411}
# 254  -  348 {'weight': 26265}
# 254  -  348 {'weight': 26265}
# 254  -  349 {'weight': 13600}
# 254  -  349 {'weight': 13600}
#
#
# Вершина, в которой находимся: 348
# Прямые потомки: [347]
# 348  -  254 {'weight': 26265}
# 348  -  254 {'weight': 26265}
# 348  -  347 {'weight': 35535}
# 348  -  347 {'weight': 35535}
# 348  -  349 {'weight': 26265}
# 348  -  349 {'weight': 26265}
#
#
# Вершина, в которой находимся: 77
# Прямые потомки: [33, 34]
# 77  -  33 {'weight': 16344}
# 77  -  33 {'weight': 16344}
# 77  -  34 {'weight': 15298}
# 77  -  34 {'weight': 15298}
# 77  -  300 {'weight': 64385}
# 77  -  300 {'weight': 64385}
# 77  -  301 {'weight': 38154}
# 77  -  301 {'weight': 38154}
#
#
# Вершина, в которой находимся: 193
# Прямые потомки: [66, 196]
# 193  -  66 {'weight': 61780}
# 193  -  66 {'weight': 61780}
# 193  -  196 {'weight': 16817}
# 193  -  196 {'weight': 16817}
# 193  -  301 {'weight': 29917}
# 193  -  301 {'weight': 29917}
#
#
# Вершина, в которой находимся: 300
# Прямые потомки: [284, 313]
# 300  -  77 {'weight': 64385}
# 300  -  77 {'weight': 64385}
# 300  -  284 {'weight': 56827}
# 300  -  284 {'weight': 56827}
# 300  -  301 {'weight': 64385}
# 300  -  301 {'weight': 64385}
# 300  -  313 {'weight': 38989}
# 300  -  313 {'weight': 38989}
#
#
# Вершина, в которой находимся: 241
# Прямые потомки: [237, 346]
# 241  -  237 {'weight': 60208}
# 241  -  237 {'weight': 60208}
# 241  -  242 {'weight': 5416}
# 241  -  242 {'weight': 5416}
# 241  -  274 {'weight': 26938}
# 241  -  274 {'weight': 26938}
# 241  -  346 {'weight': 25380}
# 241  -  346 {'weight': 25380}
#
#
# Вершина, в которой находимся: 196
# Прямые потомки: [200, 372]
# 196  -  66 {'weight': 16817}
# 196  -  66 {'weight': 16817}
# 196  -  193 {'weight': 16817}
# 196  -  193 {'weight': 16817}
# 196  -  200 {'weight': 8894}
# 196  -  200 {'weight': 8894}
# 196  -  372 {'weight': 3565}
# 196  -  372 {'weight': 3565}
#
#
# Вершина, в которой находимся: 284
# Прямые потомки: [35]
# 284  -  35 {'weight': 9830}
# 284  -  35 {'weight': 9830}
# 284  -  300 {'weight': 56827}
# 284  -  300 {'weight': 56827}
# 284  -  313 {'weight': 38989}
# 284  -  313 {'weight': 38989}
#
#
# Вершина, в которой находимся: 313
# Прямые потомки: [228, 312]
# 313  -  228 {'weight': 30177}
# 313  -  228 {'weight': 30177}
# 313  -  284 {'weight': 38989}
# 313  -  284 {'weight': 38989}
# 313  -  300 {'weight': 38989}
# 313  -  300 {'weight': 38989}
# 313  -  312 {'weight': 74974}
# 313  -  312 {'weight': 74974}
#
#
# Вершина, в которой находимся: 237
# Прямые потомки: [244, 287]
# 237  -  241 {'weight': 60208}
# 237  -  241 {'weight': 60208}
# 237  -  244 {'weight': 73593}
# 237  -  244 {'weight': 73593}
# 237  -  287 {'weight': 44939}
# 237  -  287 {'weight': 44939}
# 237  -  346 {'weight': 25380}
# 237  -  346 {'weight': 25380}
#
#
# Вершина, в которой находимся: 346
# Прямые потомки: [107, 341]
# 346  -  107 {'weight': 81254}
# 346  -  107 {'weight': 81254}
# 346  -  237 {'weight': 25380}
# 346  -  237 {'weight': 25380}
# 346  -  241 {'weight': 25380}
# 346  -  241 {'weight': 25380}
# 346  -  341 {'weight': 111274}
# 346  -  341 {'weight': 111274}
#
#
# Вершина, в которой находимся: 200
# Прямые потомки: [199, 271]
# 200  -  196 {'weight': 8894}
# 200  -  196 {'weight': 8894}
# 200  -  199 {'weight': 40434}
# 200  -  199 {'weight': 40434}
# 200  -  271 {'weight': 57670}
# 200  -  271 {'weight': 57670}
# 200  -  372 {'weight': 3565}
# 200  -  372 {'weight': 3565}
#
#
# Вершина, в которой находимся: 372
# Прямые потомки: [270, 375]
# 372  -  196 {'weight': 3565}
# 372  -  196 {'weight': 3565}
# 372  -  200 {'weight': 3565}
# 372  -  200 {'weight': 3565}
# 372  -  270 {'weight': 61202}
# 372  -  270 {'weight': 61202}
# 372  -  375 {'weight': 40165}
# 372  -  375 {'weight': 40165}
#
#
# Вершина, в которой находимся: 228
# Прямые потомки: [78, 227]
# 228  -  78 {'weight': 15964}
# 228  -  78 {'weight': 15964}
# 228  -  227 {'weight': 24401}
# 228  -  227 {'weight': 24401}
# 228  -  312 {'weight': 74974}
# 228  -  312 {'weight': 74974}
# 228  -  313 {'weight': 30177}
# 228  -  313 {'weight': 30177}
#
#
# Вершина, в которой находимся: 312
# Прямые потомки: [90, 303]
# 312  -  90 {'weight': 28627}
# 312  -  90 {'weight': 28627}
# 312  -  228 {'weight': 74974}
# 312  -  228 {'weight': 74974}
# 312  -  303 {'weight': 17138}
# 312  -  303 {'weight': 17138}
# 312  -  313 {'weight': 74974}
# 312  -  313 {'weight': 74974}
#
#
# Вершина, в которой находимся: 244
# Прямые потомки: [79, 243]
# 244  -  79 {'weight': 31577}
# 244  -  79 {'weight': 31577}
# 244  -  237 {'weight': 73593}
# 244  -  237 {'weight': 73593}
# 244  -  243 {'weight': 10800}
# 244  -  243 {'weight': 10800}
# 244  -  287 {'weight': 44939}
# 244  -  287 {'weight': 44939}
#
#
# Вершина, в которой находимся: 341
# Прямые потомки: [345, 357]
# 341  -  107 {'weight': 111274}
# 341  -  107 {'weight': 111274}
# 341  -  345 {'weight': 11719}
# 341  -  345 {'weight': 11719}
# 341  -  346 {'weight': 111274}
# 341  -  346 {'weight': 111274}
# 341  -  357 {'weight': 16388}
# 341  -  357 {'weight': 16388}
#
#
# Вершина, в которой находимся: 199
# Прямые потомки: [75, 195]
# 199  -  75 {'weight': 39191}
# 199  -  75 {'weight': 39191}
# 199  -  195 {'weight': 53477}
# 199  -  195 {'weight': 53477}
# 199  -  200 {'weight': 40434}
# 199  -  200 {'weight': 40434}
# 199  -  271 {'weight': 57670}
# 199  -  271 {'weight': 57670}
#
#
# Вершина, в которой находимся: 375
# Прямые потомки: [69, 374]
# 375  -  69 {'weight': 17784}
# 375  -  69 {'weight': 17784}
# 375  -  270 {'weight': 40165}
# 375  -  270 {'weight': 40165}
# 375  -  372 {'weight': 40165}
# 375  -  372 {'weight': 40165}
# 375  -  374 {'weight': 72689}
# 375  -  374 {'weight': 72689}
#
#
# Вершина, в которой находимся: 78
# Прямые потомки: [37, 38]
# 78  -  37 {'weight': 21873}
# 78  -  37 {'weight': 21873}
# 78  -  38 {'weight': 15597}
# 78  -  38 {'weight': 15597}
# 78  -  227 {'weight': 24401}
# 78  -  227 {'weight': 24401}
# 78  -  228 {'weight': 15964}
# 78  -  228 {'weight': 15964}
#
#
# Вершина, в которой находимся: 227
# Прямые потомки: [226, 283]
# 227  -  78 {'weight': 24401}
# 227  -  78 {'weight': 24401}
# 227  -  226 {'weight': 38937}
# 227  -  226 {'weight': 38937}
# 227  -  228 {'weight': 24401}
# 227  -  228 {'weight': 24401}
# 227  -  283 {'weight': 29604}
# 227  -  283 {'weight': 29604}
#
#
# Вершина, в которой находимся: 90
# Прямые потомки: [39, 89]
# 90  -  39 {'weight': 30378}
# 90  -  39 {'weight': 30378}
# 90  -  89 {'weight': 15058}
# 90  -  89 {'weight': 15058}
# 90  -  303 {'weight': 17138}
# 90  -  303 {'weight': 17138}
# 90  -  312 {'weight': 28627}
# 90  -  312 {'weight': 28627}
#
#
# Вершина, в которой находимся: 303
# Прямые потомки: [80, 298]
# 303  -  80 {'weight': 43140}
# 303  -  80 {'weight': 43140}
# 303  -  90 {'weight': 17138}
# 303  -  90 {'weight': 17138}
# 303  -  298 {'weight': 34421}
# 303  -  298 {'weight': 34421}
# 303  -  312 {'weight': 17138}
# 303  -  312 {'weight': 17138}
#
#
# Вершина, в которой находимся: 243
# Прямые потомки: [380]
# 243  -  79 {'weight': 10800}
# 243  -  79 {'weight': 10800}
# 243  -  244 {'weight': 10800}
# 243  -  244 {'weight': 10800}
# 243  -  380 {'weight': 64388}
# 243  -  380 {'weight': 64388}
#
#
# Вершина, в которой находимся: 345
# Прямые потомки: [129, 344]
# 345  -  129 {'weight': 36407}
# 345  -  129 {'weight': 36407}
# 345  -  341 {'weight': 11719}
# 345  -  341 {'weight': 11719}
# 345  -  344 {'weight': 4251}
# 345  -  344 {'weight': 4251}
# 345  -  357 {'weight': 16388}
# 345  -  357 {'weight': 16388}
#
#
# Вершина, в которой находимся: 357
# Прямые потомки: [127]
# 357  -  127 {'weight': 31716}
# 357  -  127 {'weight': 31716}
# 357  -  341 {'weight': 16388}
# 357  -  341 {'weight': 16388}
# 357  -  345 {'weight': 16388}
# 357  -  345 {'weight': 16388}
#
#
# Вершина, в которой находимся: 195
# Прямые потомки: [1, 194]
# 195  -  1 {'weight': 10725}
# 195  -  1 {'weight': 10725}
# 195  -  75 {'weight': 53477}
# 195  -  75 {'weight': 53477}
# 195  -  194 {'weight': 22291}
# 195  -  194 {'weight': 22291}
# 195  -  199 {'weight': 53477}
# 195  -  199 {'weight': 53477}
#
#
# Вершина, в которой находимся: 69
# Прямые потомки: [26, 68]
# 69  -  26 {'weight': 63295}
# 69  -  26 {'weight': 63295}
# 69  -  68 {'weight': 24021}
# 69  -  68 {'weight': 24021}
# 69  -  374 {'weight': 72689}
# 69  -  374 {'weight': 72689}
# 69  -  375 {'weight': 17784}
# 69  -  375 {'weight': 17784}
#
#
# Вершина, в которой находимся: 374
# Прямые потомки: [65, 373]
# 374  -  65 {'weight': 49862}
# 374  -  65 {'weight': 49862}
# 374  -  69 {'weight': 72689}
# 374  -  69 {'weight': 72689}
# 374  -  373 {'weight': 33268}
# 374  -  373 {'weight': 33268}
# 374  -  375 {'weight': 72689}
# 374  -  375 {'weight': 72689}
#
#
# Вершина, в которой находимся: 89
# Прямые потомки: [40]
# 89  -  39 {'weight': 15058}
# 89  -  39 {'weight': 15058}
# 89  -  40 {'weight': 7240}
# 89  -  40 {'weight': 7240}
# 89  -  90 {'weight': 15058}
# 89  -  90 {'weight': 15058}
#
#
# Вершина, в которой находимся: 298
# Прямые потомки: [286, 292]
# 298  -  80 {'weight': 34421}
# 298  -  80 {'weight': 34421}
# 298  -  286 {'weight': 34833}
# 298  -  286 {'weight': 34833}
# 298  -  292 {'weight': 24096}
# 298  -  292 {'weight': 24096}
# 298  -  303 {'weight': 34421}
# 298  -  303 {'weight': 34421}
#
#
# Вершина, в которой находимся: 380
# Прямые потомки: [125, 382]
# 380  -  125 {'weight': 50088}
# 380  -  125 {'weight': 50088}
# 380  -  243 {'weight': 64388}
# 380  -  243 {'weight': 64388}
# 380  -  382 {'weight': 49164}
# 380  -  382 {'weight': 49164}
#
#
# Вершина, в которой находимся: 129
# Прямые потомки: [128]
# 129  -  128 {'weight': 12894}
# 129  -  128 {'weight': 12894}
# 129  -  344 {'weight': 4251}
# 129  -  344 {'weight': 4251}
# 129  -  345 {'weight': 36407}
# 129  -  345 {'weight': 36407}
#
#
# Вершина, в которой находимся: 344
# Прямые потомки: [159, 343]
# 344  -  129 {'weight': 4251}
# 344  -  129 {'weight': 4251}
# 344  -  159 {'weight': 7374}
# 344  -  159 {'weight': 7374}
# 344  -  343 {'weight': 7691}
# 344  -  343 {'weight': 7691}
# 344  -  345 {'weight': 4251}
# 344  -  345 {'weight': 4251}
#
#
# Вершина, в которой находимся: 1
# Прямые потомки: [83, 234]
# 1  -  83 {'weight': 44336}
# 1  -  83 {'weight': 44336}
# 1  -  194 {'weight': 22291}
# 1  -  194 {'weight': 22291}
# 1  -  195 {'weight': 10725}
# 1  -  195 {'weight': 10725}
# 1  -  234 {'weight': 27120}
# 1  -  234 {'weight': 27120}
#
#
# Вершина, в которой находимся: 194
# Прямые потомки: [202, 212]
# 194  -  1 {'weight': 22291}
# 194  -  1 {'weight': 22291}
# 194  -  195 {'weight': 22291}
# 194  -  195 {'weight': 22291}
# 194  -  202 {'weight': 54662}
# 194  -  202 {'weight': 54662}
# 194  -  212 {'weight': 88427}
# 194  -  212 {'weight': 88427}
#
#
# Вершина, в которой находимся: 68
# Прямые потомки: [67, 72]
# 68  -  26 {'weight': 24021}
# 68  -  26 {'weight': 24021}
# 68  -  67 {'weight': 44134}
# 68  -  67 {'weight': 44134}
# 68  -  69 {'weight': 24021}
# 68  -  69 {'weight': 24021}
# 68  -  72 {'weight': 39333}
# 68  -  72 {'weight': 39333}
#
#
# Вершина, в которой находимся: 40
# Прямые потомки: [91]
# 40  -  89 {'weight': 7240}
# 40  -  89 {'weight': 7240}
# 40  -  91 {'weight': 23220}
# 40  -  91 {'weight': 23220}
#
#
# Вершина, в которой находимся: 286
# Прямые потомки: [260, 285]
# 286  -  260 {'weight': 49037}
# 286  -  260 {'weight': 49037}
# 286  -  285 {'weight': 53033}
# 286  -  285 {'weight': 53033}
# 286  -  292 {'weight': 24096}
# 286  -  292 {'weight': 24096}
# 286  -  298 {'weight': 34833}
# 286  -  298 {'weight': 34833}
#
#
# Вершина, в которой находимся: 292
# Прямые потомки: [302, 359]
# 292  -  286 {'weight': 24096}
# 292  -  286 {'weight': 24096}
# 292  -  298 {'weight': 24096}
# 292  -  298 {'weight': 24096}
# 292  -  302 {'weight': 15371}
# 292  -  302 {'weight': 15371}
# 292  -  359 {'weight': 46819}
# 292  -  359 {'weight': 46819}
#
#
# Вершина, в которой находимся: 382
# Прямые потомки: [340, 381]
# 382  -  125 {'weight': 49164}
# 382  -  125 {'weight': 49164}
# 382  -  340 {'weight': 7326}
# 382  -  340 {'weight': 7326}
# 382  -  380 {'weight': 49164}
# 382  -  380 {'weight': 49164}
# 382  -  381 {'weight': 34602}
# 382  -  381 {'weight': 34602}
#
#
# Вершина, в которой находимся: 159
# Прямые потомки: [342]
# 159  -  342 {'weight': 17328}
# 159  -  342 {'weight': 17328}
# 159  -  343 {'weight': 7691}
# 159  -  343 {'weight': 7691}
# 159  -  344 {'weight': 7374}
# 159  -  344 {'weight': 7374}
#
#
# Вершина, в которой находимся: 234
# Прямые потомки: [233, 282]
# 234  -  1 {'weight': 27120}
# 234  -  1 {'weight': 27120}
# 234  -  83 {'weight': 27120}
# 234  -  83 {'weight': 27120}
# 234  -  233 {'weight': 34665}
# 234  -  233 {'weight': 34665}
# 234  -  282 {'weight': 12008}
# 234  -  282 {'weight': 12008}
#
#
# Вершина, в которой находимся: 202
# Прямые потомки: [201, 277]
# 202  -  194 {'weight': 54662}
# 202  -  194 {'weight': 54662}
# 202  -  201 {'weight': 19011}
# 202  -  201 {'weight': 19011}
# 202  -  212 {'weight': 88427}
# 202  -  212 {'weight': 88427}
# 202  -  277 {'weight': 43834}
# 202  -  277 {'weight': 43834}
#
#
# Вершина, в которой находимся: 302
# Прямые потомки: [87, 311]
# 302  -  87 {'weight': 17233}
# 302  -  87 {'weight': 17233}
# 302  -  292 {'weight': 15371}
# 302  -  292 {'weight': 15371}
# 302  -  311 {'weight': 20786}
# 302  -  311 {'weight': 20786}
# 302  -  359 {'weight': 46819}
# 302  -  359 {'weight': 46819}
#
#
# Вершина, в которой находимся: 340
# Прямые потомки: [124, 339]
# 340  -  124 {'weight': 36314}
# 340  -  124 {'weight': 36314}
# 340  -  339 {'weight': 59363}
# 340  -  339 {'weight': 59363}
# 340  -  381 {'weight': 34602}
# 340  -  381 {'weight': 34602}
# 340  -  382 {'weight': 7326}
# 340  -  382 {'weight': 7326}
#
#
# Вершина, в которой находимся: 381
# Прямые потомки: [58, 384]
# 381  -  58 {'weight': 3212}
# 381  -  58 {'weight': 3212}
# 381  -  340 {'weight': 34602}
# 381  -  340 {'weight': 34602}
# 381  -  382 {'weight': 34602}
# 381  -  382 {'weight': 34602}
# 381  -  384 {'weight': 57692}
# 381  -  384 {'weight': 57692}
#
#
# Вершина, в которой находимся: 342
# Прямые потомки: [210, 364]
# 342  -  159 {'weight': 17328}
# 342  -  159 {'weight': 17328}
# 342  -  210 {'weight': 103388}
# 342  -  210 {'weight': 103388}
# 342  -  343 {'weight': 17328}
# 342  -  343 {'weight': 17328}
# 342  -  364 {'weight': 50933}
# 342  -  364 {'weight': 50933}
#
#
# Вершина, в которой находимся: 233
# Прямые потомки: [173, 416]
# 233  -  173 {'weight': 9226}
# 233  -  173 {'weight': 9226}
# 233  -  234 {'weight': 34665}
# 233  -  234 {'weight': 34665}
# 233  -  282 {'weight': 12008}
# 233  -  282 {'weight': 12008}
# 233  -  416 {'weight': 9652}
# 233  -  416 {'weight': 9652}
#
#
# Вершина, в которой находимся: 282
# Прямые потомки: [31, 281]
# 282  -  31 {'weight': 41420}
# 282  -  31 {'weight': 41420}
# 282  -  233 {'weight': 12008}
# 282  -  233 {'weight': 12008}
# 282  -  234 {'weight': 12008}
# 282  -  234 {'weight': 12008}
# 282  -  281 {'weight': 75866}
# 282  -  281 {'weight': 75866}
#
#
# Вершина, в которой находимся: 201
# Прямые потомки: [86, 198]
# 201  -  86 {'weight': 68198}
# 201  -  86 {'weight': 68198}
# 201  -  198 {'weight': 63271}
# 201  -  198 {'weight': 63271}
# 201  -  202 {'weight': 19011}
# 201  -  202 {'weight': 19011}
# 201  -  277 {'weight': 43834}
# 201  -  277 {'weight': 43834}
#
#
# Вершина, в которой находимся: 87
# Прямые потомки: [46]
# 87  -  46 {'weight': 16525}
# 87  -  46 {'weight': 16525}
# 87  -  302 {'weight': 17233}
# 87  -  302 {'weight': 17233}
# 87  -  311 {'weight': 20786}
# 87  -  311 {'weight': 20786}
#
#
# Вершина, в которой находимся: 311
# Прямые потомки: [213, 315]
# 311  -  87 {'weight': 20786}
# 311  -  87 {'weight': 20786}
# 311  -  213 {'weight': 26323}
# 311  -  213 {'weight': 26323}
# 311  -  302 {'weight': 20786}
# 311  -  302 {'weight': 20786}
# 311  -  315 {'weight': 22975}
# 311  -  315 {'weight': 22975}
#
#
# Вершина, в которой находимся: 339
# Прямые потомки: [427, 428]
# 339  -  124 {'weight': 59363}
# 339  -  124 {'weight': 59363}
# 339  -  340 {'weight': 59363}
# 339  -  340 {'weight': 59363}
# 339  -  427 {'weight': 18319}
# 339  -  427 {'weight': 18319}
# 339  -  428 {'weight': 3120}
# 339  -  428 {'weight': 3120}
#
#
# Вершина, в которой находимся: 58
# Прямые потомки: [57, 104]
# 58  -  57 {'weight': 59000}
# 58  -  57 {'weight': 59000}
# 58  -  104 {'weight': 36119}
# 58  -  104 {'weight': 36119}
# 58  -  381 {'weight': 3212}
# 58  -  381 {'weight': 3212}
# 58  -  384 {'weight': 57692}
# 58  -  384 {'weight': 57692}
#
#
# Вершина, в которой находимся: 384
# Прямые потомки: [122, 383]
# 384  -  58 {'weight': 57692}
# 384  -  58 {'weight': 57692}
# 384  -  122 {'weight': 53948}
# 384  -  122 {'weight': 53948}
# 384  -  381 {'weight': 57692}
# 384  -  381 {'weight': 57692}
# 384  -  383 {'weight': 11067}
# 384  -  383 {'weight': 11067}
#
#
# Вершина, в которой находимся: 210
# Прямые потомки: [12]
# 210  -  12 {'weight': 8032}
# 210  -  12 {'weight': 8032}
# 210  -  342 {'weight': 103388}
# 210  -  342 {'weight': 103388}
# 210  -  364 {'weight': 50933}
# 210  -  364 {'weight': 50933}
#
#
# Вершина, в которой находимся: 364
# Прямые потомки: [126, 363]
# 364  -  126 {'weight': 13583}
# 364  -  126 {'weight': 13583}
# 364  -  210 {'weight': 50933}
# 364  -  210 {'weight': 50933}
# 364  -  342 {'weight': 50933}
# 364  -  342 {'weight': 50933}
# 364  -  363 {'weight': 19675}
# 364  -  363 {'weight': 19675}
#
#
# Вершина, в которой находимся: 173
# Прямые потомки: [229, 417]
# 173  -  229 {'weight': 22080}
# 173  -  229 {'weight': 22080}
# 173  -  233 {'weight': 9226}
# 173  -  233 {'weight': 9226}
# 173  -  416 {'weight': 9652}
# 173  -  416 {'weight': 9652}
# 173  -  417 {'weight': 7395}
# 173  -  417 {'weight': 7395}
#
#
# Вершина, в которой находимся: 198
# Прямые потомки: [197, 222]
# 198  -  86 {'weight': 63271}
# 198  -  86 {'weight': 63271}
# 198  -  197 {'weight': 52377}
# 198  -  197 {'weight': 52377}
# 198  -  201 {'weight': 63271}
# 198  -  201 {'weight': 63271}
# 198  -  222 {'weight': 99283}
# 198  -  222 {'weight': 99283}
#
#
# Вершина, в которой находимся: 213
# Прямые потомки: [82, 214]
# 213  -  82 {'weight': 24235}
# 213  -  82 {'weight': 24235}
# 213  -  214 {'weight': 28571}
# 213  -  214 {'weight': 28571}
# 213  -  311 {'weight': 26323}
# 213  -  311 {'weight': 26323}
# 213  -  315 {'weight': 22975}
# 213  -  315 {'weight': 22975}
#
#
# Вершина, в которой находимся: 315
# Прямые потомки: [249, 314]
# 315  -  213 {'weight': 22975}
# 315  -  213 {'weight': 22975}
# 315  -  249 {'weight': 97104}
# 315  -  249 {'weight': 97104}
# 315  -  311 {'weight': 22975}
# 315  -  311 {'weight': 22975}
# 315  -  314 {'weight': 44507}
# 315  -  314 {'weight': 44507}
#
#
# Вершина, в которой находимся: 427
# Прямые потомки: [106, 426]
# 427  -  106 {'weight': 14711}
# 427  -  106 {'weight': 14711}
# 427  -  339 {'weight': 18319}
# 427  -  339 {'weight': 18319}
# 427  -  426 {'weight': 14137}
# 427  -  426 {'weight': 14137}
# 427  -  428 {'weight': 3120}
# 427  -  428 {'weight': 3120}
#
#
# Вершина, в которой находимся: 104
# Прямые потомки: [55]
# 104  -  55 {'weight': 9833}
# 104  -  55 {'weight': 9833}
# 104  -  57 {'weight': 36119}
# 104  -  57 {'weight': 36119}
# 104  -  58 {'weight': 36119}
# 104  -  58 {'weight': 36119}
#
#
# Вершина, в которой находимся: 229
# Прямые потомки: [71, 230]
# 229  -  71 {'weight': 59956}
# ...
# 424  -  314 {'weight': 68900}
# 424  -  314 {'weight': 68900}
# 424  -  423 {'weight': 14798}
# 424  -  423 {'weight': 14798}
# 424  -  425 {'weight': 28200}
# 424  -  425 {'weight': 28200}
#
#
# Вершина, в которой находимся: 425
# Прямые потомки: [174]
# 425  -  174 {'weight': 7574}
# 425  -  174 {'weight': 7574}
# 425  -  314 {'weight': 28200}
# 425  -  314 {'weight': 28200}
# 425  -  424 {'weight': 28200}
# 425  -  424 {'weight': 28200}
#
#
# Вершина, в которой находимся: 123
# Прямые потомки: [53]
# 123  -  53 {'weight': 11382}
# 123  -  53 {'weight': 11382}
# 123  -  105 {'weight': 21114}
# 123  -  105 {'weight': 21114}
# 123  -  106 {'weight': 21114}
# 123  -  106 {'weight': 21114}
#
#
# Вершина, в которой находимся: 232
# Прямые потомки: [231, 272]
# 232  -  70 {'weight': 28354}
# 232  -  70 {'weight': 28354}
# 232  -  230 {'weight': 28354}
# 232  -  230 {'weight': 28354}
# 232  -  231 {'weight': 79301}
# 232  -  231 {'weight': 79301}
# 232  -  272 {'weight': 76757}
# 232  -  272 {'weight': 76757}
#
#
# Вершина, в которой находимся: 192
# Прямые потомки: [191, 275]
# 192  -  189 {'weight': 8777}
# 192  -  189 {'weight': 8777}
# 192  -  190 {'weight': 8777}
# 192  -  190 {'weight': 8777}
# 192  -  191 {'weight': 153778}
# 192  -  191 {'weight': 153778}
# 192  -  275 {'weight': 74048}
# 192  -  275 {'weight': 74048}
#
#
# Вершина, в которой находимся: 85
# Прямые потомки: [52]
# 85  -  52 {'weight': 14150}
# 85  -  52 {'weight': 14150}
# 85  -  217 {'weight': 3029}
# 85  -  217 {'weight': 3029}
# 85  -  218 {'weight': 24851}
# 85  -  218 {'weight': 24851}
#
#
# Вершина, в которой находимся: 217
# Прямые потомки: [88, 219]
# 217  -  85 {'weight': 3029}
# 217  -  85 {'weight': 3029}
# 217  -  88 {'weight': 19918}
# 217  -  88 {'weight': 19918}
# 217  -  218 {'weight': 3029}
# 217  -  218 {'weight': 3029}
# 217  -  219 {'weight': 23552}
# 217  -  219 {'weight': 23552}
#
#
# Вершина, в которой находимся: 385
# Прямые потомки: [433, 434]
# 385  -  56 {'weight': 22313}
# 385  -  56 {'weight': 22313}
# 385  -  386 {'weight': 22313}
# 385  -  386 {'weight': 22313}
# 385  -  433 {'weight': 4294}
# 385  -  433 {'weight': 4294}
# 385  -  434 {'weight': 4498}
# 385  -  434 {'weight': 4498}
#
#
# Вершина, в которой находимся: 175
# Прямые потомки: [429]
# 175  -  3 {'weight': 2524}
# 175  -  3 {'weight': 2524}
# 175  -  429 {'weight': 3993}
# 175  -  429 {'weight': 3993}
# 175  -  432 {'weight': 6884}
# 175  -  432 {'weight': 6884}
#
#
# Вершина, в которой находимся: 432
# Прямые потомки: [158, 431]
# 432  -  3 {'weight': 6884}
# 432  -  3 {'weight': 6884}
# 432  -  158 {'weight': 15637}
# 432  -  158 {'weight': 15637}
# 432  -  175 {'weight': 6884}
# 432  -  175 {'weight': 6884}
# 432  -  431 {'weight': 3143}
# 432  -  431 {'weight': 3143}
#
#
# Вершина, в которой находимся: 423
# Прямые потомки: [420]
# 423  -  279 {'weight': 14798}
# 423  -  279 {'weight': 14798}
# 423  -  420 {'weight': 25005}
# 423  -  420 {'weight': 25005}
# 423  -  424 {'weight': 14798}
# 423  -  424 {'weight': 14798}
#
#
# Вершина, в которой находимся: 174
# Прямые потомки: [377, 418]
# 174  -  377 {'weight': 78781}
# 174  -  377 {'weight': 78781}
# 174  -  418 {'weight': 64410}
# 174  -  418 {'weight': 64410}
# 174  -  425 {'weight': 7574}
# 174  -  425 {'weight': 7574}
#
#
# Вершина, в которой находимся: 52
# Прямые потомки: [84]
# 52  -  84 {'weight': 22234}
# 52  -  84 {'weight': 22234}
# 52  -  85 {'weight': 14150}
# 52  -  85 {'weight': 14150}
#
#
# Вершина, в которой находимся: 219
# Прямые потомки: [138, 221]
# 219  -  88 {'weight': 23552}
# 219  -  88 {'weight': 23552}
# 219  -  138 {'weight': 13151}
# 219  -  138 {'weight': 13151}
# 219  -  217 {'weight': 23552}
# 219  -  217 {'weight': 23552}
# 219  -  221 {'weight': 72459}
# 219  -  221 {'weight': 72459}
#
#
# Вершина, в которой находимся: 433
# Прямые потомки: [162]
# 433  -  162 {'weight': 14672}
# 433  -  162 {'weight': 14672}
# 433  -  385 {'weight': 4294}
# 433  -  385 {'weight': 4294}
# 433  -  434 {'weight': 4498}
# 433  -  434 {'weight': 4498}
#
#
# Вершина, в которой находимся: 429
# Прямые потомки: [236, 430]
# 429  -  175 {'weight': 3993}
# 429  -  175 {'weight': 3993}
# 429  -  236 {'weight': 17645}
# 429  -  236 {'weight': 17645}
# 429  -  430 {'weight': 7969}
# 429  -  430 {'weight': 7969}
#
#
# Вершина, в которой находимся: 431
# Прямые потомки: [157]
# 431  -  157 {'weight': 19176}
# 431  -  157 {'weight': 19176}
# 431  -  158 {'weight': 3143}
# 431  -  158 {'weight': 3143}
# 431  -  430 {'weight': 7969}
# 431  -  430 {'weight': 7969}
# 431  -  432 {'weight': 3143}
# 431  -  432 {'weight': 3143}
#
#
# Вершина, в которой находимся: 420
# Прямые потомки: [18, 419, 422]
# 420  -  18 {'weight': 13452}
# 420  -  18 {'weight': 13452}
# 420  -  419 {'weight': 232}
# 420  -  419 {'weight': 232}
# 420  -  422 {'weight': 93281}
# 420  -  422 {'weight': 93281}
# 420  -  423 {'weight': 25005}
# 420  -  423 {'weight': 25005}
#
#
# Вершина, в которой находимся: 377
# Прямые потомки: [280, 376]
# 377  -  174 {'weight': 78781}
# 377  -  174 {'weight': 78781}
# 377  -  280 {'weight': 39830}
# 377  -  280 {'weight': 39830}
# 377  -  376 {'weight': 95748}
# 377  -  376 {'weight': 95748}
# 377  -  418 {'weight': 64410}
# 377  -  418 {'weight': 64410}
#
#
# Вершина, в которой находимся: 418
# Прямые потомки: [36, 421]
# 418  -  36 {'weight': 73114}
# 418  -  36 {'weight': 73114}
# 418  -  174 {'weight': 64410}
# 418  -  174 {'weight': 64410}
# 418  -  377 {'weight': 64410}
# 418  -  377 {'weight': 64410}
# 418  -  421 {'weight': 16015}
# 418  -  421 {'weight': 16015}
#
#
# Вершина, в которой находимся: 138
# Прямые потомки: [54]
# 138  -  54 {'weight': 35914}
# 138  -  54 {'weight': 35914}
# 138  -  219 {'weight': 13151}
# 138  -  219 {'weight': 13151}
# 138  -  221 {'weight': 72459}
# 138  -  221 {'weight': 72459}
#
#
# Вершина, в которой находимся: 221
# Прямые потомки: [133, 220]
# 221  -  133 {'weight': 21532}
# 221  -  133 {'weight': 21532}
# 221  -  138 {'weight': 72459}
# 221  -  138 {'weight': 72459}
# 221  -  219 {'weight': 72459}
# 221  -  219 {'weight': 72459}
# 221  -  220 {'weight': 39222}
# 221  -  220 {'weight': 39222}
#
#
# Вершина, в которой находимся: 162
# Прямые потомки: [163]
# 162  -  163 {'weight': 11698}
# 162  -  163 {'weight': 11698}
# 162  -  433 {'weight': 14672}
# 162  -  433 {'weight': 14672}
# 162  -  434 {'weight': 14672}
# 162  -  434 {'weight': 14672}
#
#
# Вершина, в которой находимся: 236
# Прямые потомки: [13]
# 236  -  13 {'weight': 9938}
# 236  -  13 {'weight': 9938}
# 236  -  429 {'weight': 17645}
# 236  -  429 {'weight': 17645}
# 236  -  430 {'weight': 7969}
# 236  -  430 {'weight': 7969}
#
#
# Вершина, в которой находимся: 18
# Прямые потомки: [17, 278]
# 18  -  17 {'weight': 4122}
# 18  -  17 {'weight': 4122}
# 18  -  278 {'weight': 40486}
# 18  -  278 {'weight': 40486}
# 18  -  420 {'weight': 13452}
# 18  -  420 {'weight': 13452}
#
#
# Вершина, в которой находимся: 422
# Прямые потомки: [328]
# 422  -  328 {'weight': 41646}
# 422  -  328 {'weight': 41646}
# 422  -  419 {'weight': 93281}
# 422  -  419 {'weight': 93281}
# 422  -  420 {'weight': 93281}
# 422  -  420 {'weight': 93281}
# 422  -  421 {'weight': 16015}
# 422  -  421 {'weight': 16015}
#
#
# Вершина, в которой находимся: 133
# Прямые потомки: [131]
# 133  -  131 {'weight': 28194}
# 133  -  131 {'weight': 28194}
# 133  -  220 {'weight': 39222}
# 133  -  220 {'weight': 39222}
# 133  -  221 {'weight': 21532}
# 133  -  221 {'weight': 21532}
#
#
# Вершина, в которой находимся: 220
# Прямые потомки: [121, 216]
# 220  -  121 {'weight': 17253}
# 220  -  121 {'weight': 17253}
# 220  -  133 {'weight': 39222}
# 220  -  133 {'weight': 39222}
# 220  -  216 {'weight': 16347}
# 220  -  216 {'weight': 16347}
# 220  -  221 {'weight': 39222}
# 220  -  221 {'weight': 39222}
#
#
# Вершина, в которой находимся: 17
# Прямые потомки: [16, 81]
# 17  -  16 {'weight': 78182}
# 17  -  16 {'weight': 78182}
# 17  -  18 {'weight': 4122}
# 17  -  18 {'weight': 4122}
# 17  -  81 {'weight': 47953}
# 17  -  81 {'weight': 47953}
# 17  -  278 {'weight': 40486}
# 17  -  278 {'weight': 40486}
#
#
# Вершина, в которой находимся: 328
# Прямые потомки: [255, 329]
# 328  -  255 {'weight': 1482}
# 328  -  255 {'weight': 1482}
# 328  -  329 {'weight': 32816}
# 328  -  329 {'weight': 32816}
# 328  -  421 {'weight': 41646}
# 328  -  421 {'weight': 41646}
# 328  -  422 {'weight': 41646}
# 328  -  422 {'weight': 41646}
#
#
# Вершина, в которой находимся: 131
# Прямые потомки: [130, 134]
# 131  -  130 {'weight': 34160}
# 131  -  130 {'weight': 34160}
# 131  -  133 {'weight': 28194}
# 131  -  133 {'weight': 28194}
# 131  -  134 {'weight': 35031}
# 131  -  134 {'weight': 35031}
#
#
# Вершина, в которой находимся: 121
# Прямые потомки: [120]
# 121  -  120 {'weight': 27409}
# 121  -  120 {'weight': 27409}
# 121  -  216 {'weight': 16347}
# 121  -  216 {'weight': 16347}
# 121  -  220 {'weight': 17253}
# 121  -  220 {'weight': 17253}
#
#
# Вершина, в которой находимся: 216
# Прямые потомки: [119, 215]
# 216  -  119 {'weight': 24402}
# 216  -  119 {'weight': 24402}
# 216  -  121 {'weight': 16347}
# 216  -  121 {'weight': 16347}
# 216  -  215 {'weight': 24605}
# 216  -  215 {'weight': 24605}
# 216  -  220 {'weight': 16347}
# 216  -  220 {'weight': 16347}
#
#
# Вершина, в которой находимся: 255
# Прямые потомки: [257, 258]
# 255  -  257 {'weight': 20314}
# 255  -  257 {'weight': 20314}
# 255  -  258 {'weight': 40892}
# 255  -  258 {'weight': 40892}
# 255  -  328 {'weight': 1482}
# 255  -  328 {'weight': 1482}
# 255  -  329 {'weight': 32816}
# 255  -  329 {'weight': 32816}
#
#
# Вершина, в которой находимся: 329
# Прямые потомки: [32, 331]
# 329  -  32 {'weight': 69255}
# 329  -  32 {'weight': 69255}
# 329  -  255 {'weight': 32816}
# 329  -  255 {'weight': 32816}
# 329  -  328 {'weight': 32816}
# 329  -  328 {'weight': 32816}
# 329  -  331 {'weight': 11400}
# 329  -  331 {'weight': 11400}
#
#
# Вершина, в которой находимся: 130
# Прямые потомки: [132]
# 130  -  131 {'weight': 34160}
# 130  -  131 {'weight': 34160}
# 130  -  132 {'weight': 12182}
# 130  -  132 {'weight': 12182}
# 130  -  134 {'weight': 35031}
# 130  -  134 {'weight': 35031}
#
#
# Вершина, в которой находимся: 119
# Прямые потомки: [118, 155]
# 119  -  118 {'weight': 29537}
# 119  -  118 {'weight': 29537}
# 119  -  155 {'weight': 21785}
# 119  -  155 {'weight': 21785}
# 119  -  215 {'weight': 24605}
# 119  -  215 {'weight': 24605}
# 119  -  216 {'weight': 24402}
# 119  -  216 {'weight': 24402}
#
#
# Вершина, в которой находимся: 215
# Прямые потомки: [156, 161]
# 215  -  119 {'weight': 24605}
# 215  -  119 {'weight': 24605}
# 215  -  156 {'weight': 33469}
# 215  -  156 {'weight': 33469}
# 215  -  161 {'weight': 31947}
# 215  -  161 {'weight': 31947}
# 215  -  216 {'weight': 24605}
# 215  -  216 {'weight': 24605}
#
#
# Вершина, в которой находимся: 257
# Прямые потомки: [256, 288]
# 257  -  255 {'weight': 20314}
# 257  -  255 {'weight': 20314}
# 257  -  256 {'weight': 64524}
# 257  -  256 {'weight': 64524}
# 257  -  258 {'weight': 40892}
# 257  -  258 {'weight': 40892}
# 257  -  288 {'weight': 28723}
# 257  -  288 {'weight': 28723}
#
#
# Вершина, в которой находимся: 331
# Прямые потомки: [5, 330]
# 331  -  5 {'weight': 119718}
# 331  -  5 {'weight': 119718}
# 331  -  32 {'weight': 11400}
# 331  -  32 {'weight': 11400}
# 331  -  329 {'weight': 11400}
# 331  -  329 {'weight': 11400}
# 331  -  330 {'weight': 52010}
# 331  -  330 {'weight': 52010}
#
#
# Вершина, в которой находимся: 330
# Прямые потомки: [74, 332]
# 330  -  5 {'weight': 52010}
# 330  -  5 {'weight': 52010}
# 330  -  74 {'weight': 36478}
# 330  -  74 {'weight': 36478}
# 330  -  331 {'weight': 52010}
# 330  -  331 {'weight': 52010}
# 330  -  332 {'weight': 8425}
# 330  -  332 {'weight': 8425}
#
#
# Вершина, в которой находимся: 74
# Прямые потомки: [171, 172]
# 74  -  171 {'weight': 1041}
# 74  -  171 {'weight': 1041}
# 74  -  172 {'weight': 7678}
# 74  -  172 {'weight': 7678}
# 74  -  330 {'weight': 36478}
# 74  -  330 {'weight': 36478}
# 74  -  332 {'weight': 8425}
# 74  -  332 {'weight': 8425}
#
#
# Вершина, в которой находимся: 332
# Прямые потомки: [94, 334]
# 332  -  74 {'weight': 8425}
# 332  -  74 {'weight': 8425}
# 332  -  94 {'weight': 80888}
# 332  -  94 {'weight': 80888}
# 332  -  330 {'weight': 8425}
# 332  -  330 {'weight': 8425}
# 332  -  334 {'weight': 6618}
# 332  -  334 {'weight': 6618}
#
#
# Вершина, в которой находимся: 171
# Прямые потомки: [411]
# 171  -  74 {'weight': 1041}
# 171  -  74 {'weight': 1041}
# 171  -  172 {'weight': 7678}
# 171  -  172 {'weight': 7678}
# 171  -  411 {'weight': 5941}
# 171  -  411 {'weight': 5941}
#
#
# Вершина, в которой находимся: 172
# Прямые потомки: [273]
# 172  -  74 {'weight': 7678}
# 172  -  74 {'weight': 7678}
# 172  -  171 {'weight': 7678}
# 172  -  171 {'weight': 7678}
# 172  -  273 {'weight': 22032}
# 172  -  273 {'weight': 22032}
# 172  -  411 {'weight': 5941}
# 172  -  411 {'weight': 5941}
#
#
# Вершина, в которой находимся: 334
# Прямые потомки: [206, 333]
# 334  -  94 {'weight': 6618}
# 334  -  94 {'weight': 6618}
# 334  -  206 {'weight': 43092}
# 334  -  206 {'weight': 43092}
# 334  -  332 {'weight': 6618}
# 334  -  332 {'weight': 6618}
# 334  -  333 {'weight': 18781}
# 334  -  333 {'weight': 18781}
#
#
# Вершина, в которой находимся: 273
# Прямые потомки: [181]
# 273  -  172 {'weight': 22032}
# 273  -  172 {'weight': 22032}
# 273  -  181 {'weight': 9096}
# 273  -  181 {'weight': 9096}
# 273  -  411 {'weight': 22032}
# 273  -  411 {'weight': 22032}
#
#
# Вершина, в которой находимся: 206
# Прямые потомки: [93, 205]
# 206  -  93 {'weight': 40505}
# 206  -  93 {'weight': 40505}
# 206  -  205 {'weight': 38814}
# 206  -  205 {'weight': 38814}
# 206  -  333 {'weight': 18781}
# 206  -  333 {'weight': 18781}
# 206  -  334 {'weight': 43092}
# 206  -  334 {'weight': 43092}
#
#
# Вершина, в которой находимся: 333
# Прямые потомки: [437, 438]
# 333  -  206 {'weight': 18781}
# 333  -  206 {'weight': 18781}
# 333  -  334 {'weight': 18781}
# 333  -  334 {'weight': 18781}
# 333  -  437 {'weight': 16043}
# 333  -  437 {'weight': 16043}
# 333  -  438 {'weight': 14479}
# 333  -  438 {'weight': 14479}
#
#
# Вершина, в которой находимся: 205
# Прямые потомки: [203, 204]
# 205  -  93 {'weight': 38814}
# 205  -  93 {'weight': 38814}
# 205  -  203 {'weight': 18806}
# 205  -  203 {'weight': 18806}
# 205  -  204 {'weight': 61442}
# 205  -  204 {'weight': 61442}
# 205  -  206 {'weight': 38814}
# 205  -  206 {'weight': 38814}
#
#
# Вершина, в которой находимся: 437
# Прямые потомки: [98]
# 437  -  98 {'weight': 9158}
# 437  -  98 {'weight': 9158}
# 437  -  333 {'weight': 16043}
# 437  -  333 {'weight': 16043}
# 437  -  438 {'weight': 14479}
# 437  -  438 {'weight': 14479}
#
#
# Вершина, в которой находимся: 203
# Прямые потомки: [2]
# 203  -  2 {'weight': 30189}
# 203  -  2 {'weight': 30189}
# 203  -  204 {'weight': 61442}
# 203  -  204 {'weight': 61442}
# 203  -  205 {'weight': 18806}
# 203  -  205 {'weight': 18806}
#
#
# Вершина, в которой находимся: 98
# Прямые потомки: [97, 253]
# 98  -  97 {'weight': 11480}
# 98  -  97 {'weight': 11480}
# 98  -  253 {'weight': 38019}
# 98  -  253 {'weight': 38019}
# 98  -  437 {'weight': 9158}
# 98  -  437 {'weight': 9158}
# 98  -  438 {'weight': 9158}
# 98  -  438 {'weight': 9158}
#
#
# Вершина, в которой находимся: 97
# Прямые потомки: [406]
# 97  -  98 {'weight': 11480}
# 97  -  98 {'weight': 11480}
# 97  -  253 {'weight': 38019}
# 97  -  253 {'weight': 38019}
# 97  -  406 {'weight': 28125}
# 97  -  406 {'weight': 28125}
#
#
# Вершина, в которой находимся: 253
# Прямые потомки: [27, 252]
# 253  -  27 {'weight': 23329}
# 253  -  27 {'weight': 23329}
# 253  -  97 {'weight': 38019}
# 253  -  97 {'weight': 38019}
# 253  -  98 {'weight': 38019}
# 253  -  98 {'weight': 38019}
# 253  -  252 {'weight': 47832}
# 253  -  252 {'weight': 47832}
#
#
# Вершина, в которой находимся: 406
# Прямые потомки: [407, 408]
# 406  -  97 {'weight': 28125}
# 406  -  97 {'weight': 28125}
# 406  -  407 {'weight': 31726}
# 406  -  407 {'weight': 31726}
# 406  -  408 {'weight': 9453}
# 406  -  408 {'weight': 9453}
#
#
# Вершина, в которой находимся: 407
# Прямые потомки: [336]
# 407  -  336 {'weight': 20138}
# 407  -  336 {'weight': 20138}
# 407  -  406 {'weight': 31726}
# 407  -  406 {'weight': 31726}
# 407  -  408 {'weight': 9453}
# 407  -  408 {'weight': 9453}
#
#
# Вершина, в которой находимся: 336
# Прямые потомки: [73, 335]
# 336  -  73 {'weight': 33545}
# 336  -  73 {'weight': 33545}
# 336  -  335 {'weight': 39833}
# 336  -  335 {'weight': 39833}
# 336  -  407 {'weight': 20138}
# 336  -  407 {'weight': 20138}
# 336  -  408 {'weight': 20138}
# 336  -  408 {'weight': 20138}
#
#
# Вершина, в которой находимся: 335
# Прямые потомки: [9]
# 335  -  9 {'weight': 6112}
# 335  -  9 {'weight': 6112}
# 335  -  73 {'weight': 39833}
# 335  -  73 {'weight': 39833}
# 335  -  336 {'weight': 39833}
# 335  -  336 {'weight': 39833}
#
#
# Вершина, в которой находимся: 9
# Прямые потомки: [337]
# 9  -  335 {'weight': 6112}
# 9  -  335 {'weight': 6112}
# 9  -  337 {'weight': 63528}
# 9  -  337 {'weight': 63528}

# %%
# Функция для присваивания атрибутов вершинам графа
def attr_set(G, start, last_vertex):
    
    # Обход графа с присваиванием атрибутов
    # G           --- граф как объект networkx
    # vertex      --- вершина, из которой начинается обход графа
    # kernel_path --- список вершин, входящих в главный путь, от которого строится обход
    def bfs_attributes(G, vertex, kernel_path):
        
        # Создаем копию графа
        G_copy = G.copy()
        
        # Удаляем все ребра, которые связаны с опорными вершинами
        for kernel_vertex in kernel_path:
            # Оставляем опорную вершину, из которой начинаем обход
            if kernel_vertex == vertex:
                pass
            else:
                # Для всех остальных вершин - производим удаление рёбер
                for i in G_copy.nodes():
                    try:
                        G_copy.remove_edge(i, kernel_vertex)
                    except Exception:
                        pass
                    
        # Полученный подграф изолирован от всех опорных вершин, кроме той, из которой 
        # начинается обход на данной итерации               
                        
        # Обходим граф в ширину
        all_neighbors = list(nx.bfs_successors(G_copy, source = vertex))    
        
        #########################################################################
        #                              Внимание!                                #
        # Метки присваиваются не на изолированном подграфе, а на исходном графе #
        #########################################################################
        for component in all_neighbors:
            v = component[0] # Вершина в которой находимся на данной итерации
            neighbors = component[1] # Вершины, которые являются соседними (которые мы еще не посещали)
            
            # Значение атрибута в рассматриваемой вершине
            att = G.nodes[v].get('rank')
            if att != None:
                # Значение атрибута, которое будет присвоено соседним вершинам
                att_number = att + 1

            # Смотрим на всех ближайших прямых потомков
            first_n = list(nx.bfs_successors(G, source = v, depth_limit = 1))   
            first_n = first_n[0][1]

            # Присваиваем ранги вершинам
            for i in first_n: 
                # Если соседняя вершина - главный узел на данной итерации, то пропускаем его
                # vertex - опорная точка, из которой мы начинали обход
                if i == vertex:
                    pass 
                else:
                    current_i_rank = G.nodes[i].get('rank')
                    # Если значение ранга еще не присвоено, то присваиваем его
                    if current_i_rank == None:
                        attrs = {i: {'rank': att_number}}
                        nx.set_node_attributes(G, attrs)
                    # Если ранг в данном узле уже присвоен
                    else:
                        # Алгоритм либо "смотрит назад" на вершины, которые уже посетил
                        # В таком случае мы ничего не делаем
                        # Либо алгоритм "подошел" к главному пути в графе
                        if any(i == bearing_v for bearing_v in kernel_path):
                            G.remove_edge(v, i)
                        else:
                            pass
            
            # Дополнительный "дообход"
            for v in neighbors:
                # Смотрим на всех ближайших прямых потомков
                first_n = list(nx.bfs_successors(G, source = v, depth_limit = 1))   
                first_n = first_n[0][1]

                for i in first_n: 
                    # Если соседняя вершина - главный узел на данной итерации, то пропускаем его
                    # vertex - опорная точка, из которой мы начинали обход
                    if i == vertex:
                        pass 
                    else:
                        # Алгоритм либо "смотрит назад" на вершины, которые уже посетил
                        # В таком случае мы ничего не делаем
                        # Либо алгоритм "подошел" к главному пути в графе
                        if any(i == bearing_v for bearing_v in kernel_path):
                            G.remove_edge(v, i)
                        else:
                            pass               
    
    # Поиск кратчайшего пути A* - строим маршрут, вокруг которого будем строить последующий обход
    a_path = list(nx.astar_path(G, source = start, target = last_vertex, weight = 'weight'))
    #######################################
    # Блок проверки корректности маршрута #
    #######################################
    true_a_path = []
    for index, V in enumerate(a_path):
        
        if index == 0:
            true_a_path.append(V)
        elif index == (len(a_path) - 1):
            true_a_path.append(V)
        else:
            # Предыдущая и последующая вершины для опорного маршрута
            V_prev = a_path[index - 1]
            V_next = a_path[index + 1]
            
            # Какие вершины соседствуют с данной
            V_prev_neighborhood = list(nx.bfs_successors(G, source = V_prev, depth_limit = 1)) 
            V_prev_neighborhood = V_prev_neighborhood[0][1]
            V_next_neighborhood = list(nx.bfs_successors(G, source = V_next, depth_limit = 1))
            V_next_neighborhood = V_next_neighborhood[0][1]
            
            if any(V_next == VPREV for VPREV in V_prev_neighborhood):
                if any(V_prev == VNEXT for VNEXT in V_next_neighborhood):
                    pass
                else:
                    true_a_path.append(V)
            else:
                true_a_path.append(V)         
    
    #######################################
    # Блок проверки корректности маршрута #
    #######################################
    # Проверка закончена
    a_path = true_a_path     
    RANK = 1
    for v in a_path:
        # Начальной вершине присвоим значением атрибута - 1, чем дальше, тем больше значение
        attrs = {v: {'rank' : RANK}}
        nx.set_node_attributes(G, attrs) 
        RANK += 1

    # Основной маршрут готов, затем мы итеративно будем продвигаться от каждого узла
    for index, vertex in enumerate(a_path):
        # Начальная вершина
        if index == 0:
            next_vertex = a_path[index + 1]
            
            # Размыкаем вершины 
            G.remove_edge(vertex, next_vertex)           
            
            # Блок обхода подграфа в ширину
            bfs_attributes(G, vertex = vertex, kernel_path = a_path)      
            
            # Смыкаем вершины обратно
            G.add_edge(vertex, next_vertex)
    
        # Замыкающая вершина
        elif index == (len(a_path) - 1):
            prev_vertex = a_path[index - 1]
            
            # Размыкаем вершины 
            G.remove_edge(prev_vertex, vertex)
            
            # Блок обхода подграфа в ширину
            bfs_attributes(G, vertex = vertex, kernel_path = a_path)
            
            # Смыкаем вершины обратно
            G.add_edge(prev_vertex, vertex)
            
        # Вершины, которые являются не первыми и не последними
        else:
            prev_vertex = a_path[index - 1]
            next_vertex = a_path[index + 1]
            
            # Размыкаем вершины 
            G.remove_edge(prev_vertex, vertex)
            G.remove_edge(vertex, next_vertex)
            
            # Блок обхода подграфа в ширину
            bfs_attributes(G, vertex = vertex, kernel_path = a_path)
            
            # Замыкаем вершины 
            G.add_edge(prev_vertex, vertex)
            G.add_edge(vertex, next_vertex)
    
    # Блок присваивания атрибута - количество потомков 
    vert_list = list(nx.bfs_successors(G, source = start)) 
    for component in vert_list:
        vertex = component[0] # Вершина в которой находимся на данной итерации
        neighbors = component[1] # Вершины, которые являются соседними (которые мы еще не посещали)
        
        # Добавление атрибута - количество потомков у данной вершины
        n_offspring = len(neighbors)
        attrs = {vertex: {'offspring' : n_offspring}}
        nx.set_node_attributes(G, attrs)

attr_set(G, 293, last_vertex)

# %% [markdown]
# ## Присваивание атрибута value

# %%
# Функция для определения порядка сегментов реки по аналогии с методом Шреве
def set_values(G, start):    
    # Список со всеми вершинами, до которых можно добраться из точки start
    # при помощи поиска в ширину
    vert_list = list(nx.bfs_successors(G, source = start)) 

    # Цикл обхода графа с присваиванием меток вершинам
    # Каждая компонента - это небольшой подграф
    for component in vert_list:
        vertex = component[0] # Вершина в которой находимся на данной итерации
        neighbors = component[1] # Вершины, которые являются соседними (которые мы еще не посещали)
        
        att_rank = G.nodes[vertex].get('rank')
        att_offspring = G.nodes[vertex].get('offspring')
        
        # Для замыкающего сегмента производим следующую процедуру:
        if att_rank == 1:
            # Определяем потомков
            offspring = list(nx.bfs_successors(G, source = vertex, depth_limit = 1)) 
            # Используем только ближайших к данной вершине соседей (прямых потомков)
            offspring = offspring[0][1]
            
            # Записываем в список значения атрибутов value у всех потомков
            last_values = []
            for child in offspring:
                if G.nodes[child].get('value') != None:
                    last_values.append(G.nodes[child].get('value'))
                else:
                    last_values.append(0)
                    
            last_values = np.array(last_values)
            sum_values = np.sum(last_values)
            
            # Если сумма не равна 0, то атрибут присваивается
            if sum_values != 0:
                attrs = {vertex: {'value' : sum_values}}
                nx.set_node_attributes(G, attrs)
            # Иначе алгоритм просто еще не дошел, пропускаем этот пункт
            else:
                pass
            
        # Для каждого соседа производим присваивание атрибута
        for i in neighbors:
            # Значение атрибутов в рассматриваемой вершине
            att_rank = G.nodes[i].get('rank')
            att_offspring = G.nodes[i].get('offspring')
            
            # Если у вершины на предыдущем этапе не было найдено потомков, то ей присваивается значение 1
            if att_offspring == None:
                attrs = {i: {'value' : 1}}
                nx.set_node_attributes(G, attrs)            
            # Если вершина имеет потомков, то необходимо определить значения атрибута "value" в них
            else:
                # Производим поиск всех потомков
                offspring = list(nx.bfs_successors(G, source = i, depth_limit = 1)) 
                # Используем только ближайших к данной вершине соседей (прямых потомков)
                offspring = offspring[0][1]

                # Цикл определения значений в вершинах - потомках
                last_values = []
                for child in offspring:
                    # Нужны только те потомки, значение ранга которых строго больше, чем у рассматриваемой вершины
                    if G.nodes[child].get('rank') > att_rank:
                        if G.nodes[child].get('value') != None:
                            last_values.append(G.nodes[child].get('value'))
                        else:
                            pass
                    else:
                        pass
                    
                last_values = np.array(last_values)
                sum_values = np.sum(last_values)
                
                # Если сумма не равна 0, то атрибут присваивается
                if sum_values != 0:
                    attrs = {i: {'value' : sum_values}}
                    nx.set_node_attributes(G, attrs)
                # Иначе алгоритм просто еще не дошел, пропускаем этот пункт
                else:
                    pass

# Поскольку мы начинаем обход графа из стартовой точки, то нам необходимо производить несколько итераций последовательно
# Функция для итеративного обхода
def iter_sets(G, start):
    # Определяем максимальное значение ранга в данном графе
    ranks = []
    for vertex in list(G.nodes()):
        ranks.append(G.nodes[vertex].get('rank'))
    max_rank = max(ranks) 
    
    # Мы должны проитерировать ровно столько раз, сколько рангов есть в графе
    for iteration in range(0, max_rank):
        set_values(G, start)
        
        
# Применение алгоритма
start = timeit.default_timer()  # Засекаем время

# Применение алгоритма: запускаем функцию iter_sets
iter_sets(G, 293)

print('Runtime -', timeit.default_timer() - start, '\n')
# Out:
# Runtime - 0.3970869570002833

# %% [markdown]
# Таким образом обход графа производится в 2 этапа:
#
# 1) Присваивание вершинам графа атрибута 'rank', где значение ранга равно 1 для замыкающего сегмента, 2 - для всех его притоков, 3 - для всех притоков 2го ранга и т.д. Также вершинам присваивается атрибут 'offspring' - количество прямых потомков у данной вершины (значение ранга потомков всегда на 1 больше, чем у рассматриваемой вершины)
#
# 2) Присваивание вершинам графа атрибута 'value' на основе количества потомков у вершин и их ранга. При этом, отсутствие прямых потомков у вершины свидетельствует о том, что данный сегмент не имеет притоков и должен получить значение 'value' - 1.
#
# Визуализация процесса работы алгоритма:
#
# ![animation_graph.gif](https://raw.githubusercontent.com/Dreamlone/State_Hydrological_Institute/master/images/animation_graph.gif)

# %% [markdown]
# ## Заполнение атрибутивной таблицы для векторного слоя
#
# Мы построили и обошли граф, теперь необходимо сохранить результаты.

# %%
# Составляем датасет, где каждая вершина - строка
def make_dataframe(G):    
    dataframe = []
    for vertex in list(G.nodes()):
        rank = G.nodes[vertex].get('rank')
        value = G.nodes[vertex].get('value')
        dataframe.append([vertex, rank, value])

    dataframe = pd.DataFrame(dataframe, columns = ['id', 'Rank', 'Value'])
    return(dataframe)
    
dataframe = make_dataframe(G)

# Загружаем исходный слой с реками
rivers = geopandas.read_file('/media/mikhail/Data1/Ob/URAL_test/split_with_length.shp')

# Объединяем датасеты
data_merged = pd.merge(rivers, dataframe, on = 'id')
# Сохраняем в файл
data_merged.to_file("/media/mikhail/Data1/Ob/URAL_test/Result.shp")
